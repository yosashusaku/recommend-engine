# %%
# !pip install lightfm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lightfm in /usr/local/lib/python3.7/dist-packages (1.16)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from lightfm) (1.21.6)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from lightfm) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from lightfm) (1.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from lightfm) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->lightfm) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->lightfm) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->lightfm) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->lightfm) (2022.5.18.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->lightfm) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->lightfm) (1.1.0)

# %%
import time
from zipfile import ZipFile
from urllib.request import urlretrieve
import itertools
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
from lightfm import LightFM
from lightfm.data import Dataset

# %%
ML1M_URL = 'http://files.grouplens.org/datasets/movielens/ml-1m.zip'
# MovieLens 1Mデータをダウンロード
urlretrieve(ML1M_URL, 'movielens.zip')
# Zipを解凍
ZipFile('movielens.zip', 'r').extractall()

# %%
#　ユーザ特徴量データ
df_user = pd.read_csv(
  'ml-1m/users.dat', 
  sep='::', 
  names=[
    'user_id', 'sex', 'age_group', 
    'occupation', 'zip_code'
  ]
)
# アイテム特徴量データ
df_item = pd.read_csv(
  'ml-1m/movies.dat', 
  sep='::', 
  names=['item_id', 'title', 'genres']
)
# ユーザ-アイテムインタラクションデータ
dataset = pd.read_csv(
  'ml-1m/ratings.dat', 
  sep='::', 
  names=['user_id', 'item_id', 'rating', 'timestamp']
)
uq_users = np.sort(dataset.user_id.unique().tolist())
uq_items = np.sort(dataset.item_id.unique().tolist())
n_users = len(uq_users)
n_items = len(uq_items)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)

# %%
topk = 10
rank_list = [i+1 for i in range(topk)]
latent = 50

# %%
print('df_user:', df_user.head())
print('df_item:', df_item.head())
print('dataset:', dataset.head())
print('user list:', uq_users)
print('item list:', uq_items)
print('user number:', n_users)
print('item number:', n_items)
# Out:
# df_user:    user_id sex  age_group  occupation zip_code
# 0        1   F          1          10    48067
# 1        2   M         56          16    70072
# 2        3   M         25          15    55117
# 3        4   M         45           7    02460
# 4        5   M         25          20    55455
# df_item:    item_id                               title                        genres
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy
# dataset:    user_id  item_id  rating  timestamp
# 0        1     1193       5  978300760
# 1        1      661       3  978302109
# 2        1      914       3  978301968
# 3        1     3408       4  978300275
# 4        1     2355       5  978824291
# user list: [   1    2    3 ... 6038 6039 6040]
# item list: [   1    2    3 ... 3950 3951 3952]
# user number: 6040
# item number: 3706

# %%
# 各ユーザの特徴量を格納するリスト
uq_user_features = []
# ユーザの特徴量カラムとなる集合(重複なし)
set_user_features = set()

# 各ユーザに対してLightFM用の特徴量データを作成する
for row in df_user.itertuples():
  user_features = {}
  dict_row = []

  # 基点ユーザの特徴量をone-hot化しリストとして持つ
  user_features['sex-'+row.sex] = 1
  user_features['age_group-'+str(row.age_group)] = 1
  user_features['occupation-'+str(row.occupation)] = 1

  # ユーザー特徴量カラムに追加する
  set_user_features.add('sex-'+row.sex)
  set_user_features.add(
    'age_group-'+str(row.age_group)
  )
  set_user_features.add(
    'occupation-'+str(row.occupation)
  )
  
  # ユーザーIDと特徴量をリストに格納する
  dict_row.append(row.user_id)
  dict_row.append(user_features)
  uq_user_features.append(dict_row)

# %%
uq_user_features
# Out:
# [[1, {'age_group-1': 1, 'occupation-10': 1, 'sex-F': 1}],
#  [2, {'age_group-56': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [3, {'age_group-25': 1, 'occupation-15': 1, 'sex-M': 1}],
#  [4, {'age_group-45': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [5, {'age_group-25': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [6, {'age_group-50': 1, 'occupation-9': 1, 'sex-F': 1}],
#  [7, {'age_group-35': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [8, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [9, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [10, {'age_group-35': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [11, {'age_group-25': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [12, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [13, {'age_group-45': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [14, {'age_group-35': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [15, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [16, {'age_group-35': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [17, {'age_group-50': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [18, {'age_group-18': 1, 'occupation-3': 1, 'sex-F': 1}],
#  [19, {'age_group-1': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [20, {'age_group-25': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [21, {'age_group-18': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [22, {'age_group-18': 1, 'occupation-15': 1, 'sex-M': 1}],
#  [23, {'age_group-35': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [24, {'age_group-25': 1, 'occupation-7': 1, 'sex-F': 1}],
#  [25, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [26, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [27, {'age_group-25': 1, 'occupation-11': 1, 'sex-M': 1}],
#  [28, {'age_group-25': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [29, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [30, {'age_group-35': 1, 'occupation-7': 1, 'sex-F': 1}],
#  [31, {'age_group-56': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [32, {'age_group-25': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [33, {'age_group-45': 1, 'occupation-3': 1, 'sex-M': 1}],
#  [34, {'age_group-18': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [35, {'age_group-45': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [36, {'age_group-25': 1, 'occupation-3': 1, 'sex-M': 1}],
#  [37, {'age_group-25': 1, 'occupation-9': 1, 'sex-F': 1}],
#  [38, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [39, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [40, {'age_group-45': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [41, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [42, {'age_group-25': 1, 'occupation-8': 1, 'sex-M': 1}],
#  [43, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [44, {'age_group-45': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [45, {'age_group-45': 1, 'occupation-16': 1, 'sex-F': 1}],
#  [46, {'age_group-18': 1, 'occupation-19': 1, 'sex-M': 1}],
#  [47, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [48, {'age_group-25': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [49, {'age_group-18': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [50, {'age_group-25': 1, 'occupation-2': 1, 'sex-F': 1}],
#  [51, {'age_group-1': 1, 'occupation-10': 1, 'sex-F': 1}],
#  [52, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [53, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [54, {'age_group-50': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [55, {'age_group-35': 1, 'occupation-12': 1, 'sex-F': 1}],
#  [56, {'age_group-35': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [57, {'age_group-18': 1, 'occupation-19': 1, 'sex-M': 1}],
#  [58, {'age_group-25': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [59, {'age_group-50': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [60, {'age_group-50': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [61, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [62, {'age_group-35': 1, 'occupation-3': 1, 'sex-F': 1}],
#  [63, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [64, {'age_group-18': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [65, {'age_group-35': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [66, {'age_group-25': 1, 'occupation-18': 1, 'sex-M': 1}],
#  [67, {'age_group-50': 1, 'occupation-5': 1, 'sex-F': 1}],
#  [68, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [69, {'age_group-25': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [70, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [71, {'age_group-25': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [72, {'age_group-45': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [73, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [74, {'age_group-35': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [75, {'age_group-1': 1, 'occupation-10': 1, 'sex-F': 1}],
#  [76, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [77, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [78, {'age_group-45': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [79, {'age_group-45': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [80, {'age_group-56': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [81, {'age_group-25': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [82, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [83, {'age_group-25': 1, 'occupation-2': 1, 'sex-F': 1}],
#  [84, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [85, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [86, {'age_group-1': 1, 'occupation-10': 1, 'sex-F': 1}],
#  [87, {'age_group-25': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [88, {'age_group-45': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [89, {'age_group-56': 1, 'occupation-9': 1, 'sex-F': 1}],
#  [90, {'age_group-56': 1, 'occupation-13': 1, 'sex-M': 1}],
#  [91, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [92, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [93, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [94, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [95, {'age_group-45': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [96, {'age_group-25': 1, 'occupation-16': 1, 'sex-F': 1}],
#  [97, {'age_group-35': 1, 'occupation-3': 1, 'sex-F': 1}],
#  [98, {'age_group-35': 1, 'occupation-7': 1, 'sex-F': 1}],
#  [99, {'age_group-1': 1, 'occupation-10': 1, 'sex-F': 1}],
#  [100, {'age_group-35': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [101, {'age_group-18': 1, 'occupation-3': 1, 'sex-F': 1}],
#  [102, {'age_group-35': 1, 'occupation-19': 1, 'sex-M': 1}],
#  [103, {'age_group-45': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [104, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [105, {'age_group-45': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [106, {'age_group-35': 1, 'occupation-11': 1, 'sex-F': 1}],
#  [107, {'age_group-45': 1, 'occupation-18': 1, 'sex-M': 1}],
#  [108, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [109, {'age_group-45': 1, 'occupation-15': 1, 'sex-M': 1}],
#  [110, {'age_group-25': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [111, {'age_group-35': 1, 'occupation-15': 1, 'sex-M': 1}],
#  [112, {'age_group-25': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [113, {'age_group-18': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [114, {'age_group-25': 1, 'occupation-2': 1, 'sex-F': 1}],
#  [115, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [116, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [117, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [118, {'age_group-35': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [119, {'age_group-1': 1, 'occupation-10': 1, 'sex-F': 1}],
#  [120, {'age_group-25': 1, 'occupation-11': 1, 'sex-M': 1}],
#  [121, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [122, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [123, {'age_group-35': 1, 'occupation-9': 1, 'sex-M': 1}],
#  [124, {'age_group-56': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [125, {'age_group-45': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [126, {'age_group-18': 1, 'occupation-9': 1, 'sex-M': 1}],
#  [127, {'age_group-45': 1, 'occupation-3': 1, 'sex-F': 1}],
#  [128, {'age_group-56': 1, 'occupation-6': 1, 'sex-M': 1}],
#  [129, {'age_group-25': 1, 'occupation-11': 1, 'sex-M': 1}],
#  [130, {'age_group-35': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [131, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [132, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [133, {'age_group-25': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [134, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [135, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [136, {'age_group-18': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [137, {'age_group-45': 1, 'occupation-6': 1, 'sex-F': 1}],
#  [138, {'age_group-18': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [139, {'age_group-25': 1, 'occupation-20': 1, 'sex-F': 1}],
#  [140, {'age_group-35': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [141, {'age_group-35': 1, 'occupation-13': 1, 'sex-M': 1}],
#  [142, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [143, {'age_group-18': 1, 'occupation-3': 1, 'sex-M': 1}],
#  [144, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [145, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [146, {'age_group-35': 1, 'occupation-20': 1, 'sex-F': 1}],
#  [147, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [148, {'age_group-50': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [149, {'age_group-25': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [150, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [151, {'age_group-25': 1, 'occupation-20': 1, 'sex-F': 1}],
#  [152, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [153, {'age_group-1': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [154, {'age_group-50': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [155, {'age_group-35': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [156, {'age_group-45': 1, 'occupation-7': 1, 'sex-F': 1}],
#  [157, {'age_group-35': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [158, {'age_group-56': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [159, {'age_group-45': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [160, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [161, {'age_group-45': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [162, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [163, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [164, {'age_group-56': 1, 'occupation-13': 1, 'sex-F': 1}],
#  [165, {'age_group-18': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [166, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [167, {'age_group-25': 1, 'occupation-11': 1, 'sex-F': 1}],
#  [168, {'age_group-50': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [169, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [170, {'age_group-25': 1, 'occupation-11': 1, 'sex-M': 1}],
#  [171, {'age_group-50': 1, 'occupation-17': 1, 'sex-F': 1}],
#  [172, {'age_group-25': 1, 'occupation-3': 1, 'sex-M': 1}],
#  [173, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [174, {'age_group-25': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [175, {'age_group-25': 1, 'occupation-2': 1, 'sex-F': 1}],
#  [176, {'age_group-18': 1, 'occupation-3': 1, 'sex-F': 1}],
#  [177, {'age_group-50': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [178, {'age_group-56': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [179, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [180, {'age_group-45': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [181, {'age_group-18': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [182, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [183, {'age_group-45': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [184, {'age_group-25': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [185, {'age_group-45': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [186, {'age_group-18': 1, 'occupation-5': 1, 'sex-M': 1}],
#  [187, {'age_group-45': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [188, {'age_group-56': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [189, {'age_group-18': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [190, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [191, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [192, {'age_group-18': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [193, {'age_group-45': 1, 'occupation-15': 1, 'sex-F': 1}],
#  [194, {'age_group-1': 1, 'occupation-10': 1, 'sex-F': 1}],
#  [195, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [196, {'age_group-35': 1, 'occupation-9': 1, 'sex-F': 1}],
#  [197, {'age_group-18': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [198, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [199, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [200, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [201, {'age_group-35': 1, 'occupation-2': 1, 'sex-F': 1}],
#  [202, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [203, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [204, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [205, {'age_group-35': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [206, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [207, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [208, {'age_group-35': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [209, {'age_group-35': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [210, {'age_group-1': 1, 'occupation-10': 1, 'sex-F': 1}],
#  [211, {'age_group-45': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [212, {'age_group-25': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [213, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [214, {'age_group-18': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [215, {'age_group-35': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [216, {'age_group-45': 1, 'occupation-13': 1, 'sex-M': 1}],
#  [217, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [218, {'age_group-35': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [219, {'age_group-25': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [220, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [221, {'age_group-25': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [222, {'age_group-25': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [223, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [224, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [225, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [226, {'age_group-35': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [227, {'age_group-35': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [228, {'age_group-25': 1, 'occupation-15': 1, 'sex-M': 1}],
#  [229, {'age_group-18': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [230, {'age_group-45': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [231, {'age_group-25': 1, 'occupation-3': 1, 'sex-M': 1}],
#  [232, {'age_group-25': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [233, {'age_group-45': 1, 'occupation-20': 1, 'sex-F': 1}],
#  [234, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [235, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [236, {'age_group-25': 1, 'occupation-5': 1, 'sex-M': 1}],
#  [237, {'age_group-25': 1, 'occupation-6': 1, 'sex-M': 1}],
#  [238, {'age_group-50': 1, 'occupation-7': 1, 'sex-F': 1}],
#  [239, {'age_group-18': 1, 'occupation-19': 1, 'sex-M': 1}],
#  [240, {'age_group-50': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [241, {'age_group-35': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [242, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [243, {'age_group-25': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [244, {'age_group-50': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [245, {'age_group-35': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [246, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [247, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [248, {'age_group-18': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [249, {'age_group-18': 1, 'occupation-14': 1, 'sex-F': 1}],
#  [250, {'age_group-35': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [251, {'age_group-56': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [252, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [253, {'age_group-25': 1, 'occupation-11': 1, 'sex-F': 1}],
#  [254, {'age_group-35': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [255, {'age_group-35': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [256, {'age_group-45': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [257, {'age_group-18': 1, 'occupation-18': 1, 'sex-M': 1}],
#  [258, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [259, {'age_group-25': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [260, {'age_group-18': 1, 'occupation-19': 1, 'sex-M': 1}],
#  [261, {'age_group-25': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [262, {'age_group-25': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [263, {'age_group-25': 1, 'occupation-7': 1, 'sex-F': 1}],
#  [264, {'age_group-35': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [265, {'age_group-35': 1, 'occupation-7': 1, 'sex-F': 1}],
#  [266, {'age_group-35': 1, 'occupation-11': 1, 'sex-M': 1}],
#  [267, {'age_group-45': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [268, {'age_group-18': 1, 'occupation-12': 1, 'sex-F': 1}],
#  [269, {'age_group-25': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [270, {'age_group-50': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [271, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [272, {'age_group-18': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [273, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [274, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [275, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [276, {'age_group-45': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [277, {'age_group-35': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [278, {'age_group-45': 1, 'occupation-18': 1, 'sex-M': 1}],
#  [279, {'age_group-25': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [280, {'age_group-50': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [281, {'age_group-35': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [282, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [283, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [284, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [285, {'age_group-35': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [286, {'age_group-25': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [287, {'age_group-50': 1, 'occupation-13': 1, 'sex-M': 1}],
#  [288, {'age_group-25': 1, 'occupation-12': 1, 'sex-F': 1}],
#  [289, {'age_group-25': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [290, {'age_group-25': 1, 'occupation-20': 1, 'sex-F': 1}],
#  [291, {'age_group-35': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [292, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [293, {'age_group-56': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [294, {'age_group-45': 1, 'occupation-9': 1, 'sex-F': 1}],
#  [295, {'age_group-18': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [296, {'age_group-50': 1, 'occupation-5': 1, 'sex-M': 1}],
#  [297, {'age_group-18': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [298, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [299, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [300, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [301, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [302, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [303, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [304, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [305, {'age_group-18': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [306, {'age_group-18': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [307, {'age_group-50': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [308, {'age_group-25': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [309, {'age_group-25': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [310, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [311, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [312, {'age_group-50': 1, 'occupation-2': 1, 'sex-F': 1}],
#  [313, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [314, {'age_group-56': 1, 'occupation-9': 1, 'sex-F': 1}],
#  [315, {'age_group-56': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [316, {'age_group-56': 1, 'occupation-13': 1, 'sex-M': 1}],
#  [317, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [318, {'age_group-56': 1, 'occupation-13': 1, 'sex-F': 1}],
#  [319, {'age_group-50': 1, 'occupation-6': 1, 'sex-F': 1}],
#  [320, {'age_group-35': 1, 'occupation-6': 1, 'sex-M': 1}],
#  [321, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [322, {'age_group-56': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [323, {'age_group-45': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [324, {'age_group-35': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [325, {'age_group-50': 1, 'occupation-3': 1, 'sex-F': 1}],
#  [326, {'age_group-50': 1, 'occupation-11': 1, 'sex-M': 1}],
#  [327, {'age_group-35': 1, 'occupation-18': 1, 'sex-M': 1}],
#  [328, {'age_group-35': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [329, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [330, {'age_group-56': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [331, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [332, {'age_group-50': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [333, {'age_group-35': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [334, {'age_group-56': 1, 'occupation-2': 1, 'sex-F': 1}],
#  [335, {'age_group-35': 1, 'occupation-18': 1, 'sex-M': 1}],
#  [336, {'age_group-18': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [337, {'age_group-18': 1, 'occupation-19': 1, 'sex-M': 1}],
#  [338, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [339, {'age_group-50': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [340, {'age_group-25': 1, 'occupation-3': 1, 'sex-F': 1}],
#  [341, {'age_group-56': 1, 'occupation-13': 1, 'sex-F': 1}],
#  [342, {'age_group-18': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [343, {'age_group-35': 1, 'occupation-3': 1, 'sex-F': 1}],
#  [344, {'age_group-35': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [345, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [346, {'age_group-25': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [347, {'age_group-56': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [348, {'age_group-50': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [349, {'age_group-1': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [350, {'age_group-45': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [351, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [352, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [353, {'age_group-35': 1, 'occupation-7': 1, 'sex-F': 1}],
#  [354, {'age_group-35': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [355, {'age_group-18': 1, 'occupation-3': 1, 'sex-M': 1}],
#  [356, {'age_group-56': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [357, {'age_group-18': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [358, {'age_group-56': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [359, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [360, {'age_group-35': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [361, {'age_group-25': 1, 'occupation-14': 1, 'sex-F': 1}],
#  [362, {'age_group-35': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [363, {'age_group-18': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [364, {'age_group-35': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [365, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [366, {'age_group-50': 1, 'occupation-15': 1, 'sex-M': 1}],
#  [367, {'age_group-50': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [368, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [369, {'age_group-35': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [370, {'age_group-18': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [371, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [372, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [373, {'age_group-25': 1, 'occupation-2': 1, 'sex-F': 1}],
#  [374, {'age_group-35': 1, 'occupation-14': 1, 'sex-F': 1}],
#  [375, {'age_group-25': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [376, {'age_group-35': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [377, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [378, {'age_group-18': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [379, {'age_group-35': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [380, {'age_group-25': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [381, {'age_group-35': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [382, {'age_group-35': 1, 'occupation-20': 1, 'sex-F': 1}],
#  [383, {'age_group-25': 1, 'occupation-7': 1, 'sex-F': 1}],
#  [384, {'age_group-25': 1, 'occupation-11': 1, 'sex-M': 1}],
#  [385, {'age_group-25': 1, 'occupation-6': 1, 'sex-M': 1}],
#  [386, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [387, {'age_group-35': 1, 'occupation-7': 1, 'sex-F': 1}],
#  [388, {'age_group-25': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [389, {'age_group-25': 1, 'occupation-6': 1, 'sex-M': 1}],
#  [390, {'age_group-25': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [391, {'age_group-45': 1, 'occupation-11': 1, 'sex-M': 1}],
#  [392, {'age_group-18': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [393, {'age_group-35': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [394, {'age_group-18': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [395, {'age_group-18': 1, 'occupation-5': 1, 'sex-M': 1}],
#  [396, {'age_group-25': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [397, {'age_group-35': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [398, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [399, {'age_group-35': 1, 'occupation-6': 1, 'sex-F': 1}],
#  [400, {'age_group-18': 1, 'occupation-3': 1, 'sex-F': 1}],
#  [401, {'age_group-18': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [402, {'age_group-25': 1, 'occupation-11': 1, 'sex-M': 1}],
#  [403, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [404, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [405, {'age_group-56': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [406, {'age_group-25': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [407, {'age_group-18': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [408, {'age_group-25': 1, 'occupation-11': 1, 'sex-M': 1}],
#  [409, {'age_group-18': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [410, {'age_group-25': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [411, {'age_group-45': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [412, {'age_group-35': 1, 'occupation-15': 1, 'sex-M': 1}],
#  [413, {'age_group-25': 1, 'occupation-11': 1, 'sex-M': 1}],
#  [414, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [415, {'age_group-35': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [416, {'age_group-45': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [417, {'age_group-25': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [418, {'age_group-25': 1, 'occupation-3': 1, 'sex-F': 1}],
#  [419, {'age_group-18': 1, 'occupation-3': 1, 'sex-M': 1}],
#  [420, {'age_group-35': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [421, {'age_group-45': 1, 'occupation-3': 1, 'sex-F': 1}],
#  [422, {'age_group-56': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [423, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [424, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [425, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [426, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [427, {'age_group-35': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [428, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [429, {'age_group-18': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [430, {'age_group-18': 1, 'occupation-10': 1, 'sex-F': 1}],
#  [431, {'age_group-18': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [432, {'age_group-45': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [433, {'age_group-50': 1, 'occupation-6': 1, 'sex-M': 1}],
#  [434, {'age_group-45': 1, 'occupation-3': 1, 'sex-F': 1}],
#  [435, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [436, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [437, {'age_group-35': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [438, {'age_group-18': 1, 'occupation-11': 1, 'sex-M': 1}],
#  [439, {'age_group-35': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [440, {'age_group-56': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [441, {'age_group-35': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [442, {'age_group-25': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [443, {'age_group-25': 1, 'occupation-3': 1, 'sex-M': 1}],
#  [444, {'age_group-56': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [445, {'age_group-45': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [446, {'age_group-50': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [447, {'age_group-45': 1, 'occupation-11': 1, 'sex-F': 1}],
#  [448, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [449, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [450, {'age_group-45': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [451, {'age_group-56': 1, 'occupation-13': 1, 'sex-M': 1}],
#  [452, {'age_group-50': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [453, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [454, {'age_group-25': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [455, {'age_group-35': 1, 'occupation-2': 1, 'sex-F': 1}],
#  [456, {'age_group-35': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [457, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [458, {'age_group-50': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [459, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [460, {'age_group-45': 1, 'occupation-18': 1, 'sex-M': 1}],
#  [461, {'age_group-50': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [462, {'age_group-18': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [463, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [464, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [465, {'age_group-18': 1, 'occupation-19': 1, 'sex-M': 1}],
#  [466, {'age_group-25': 1, 'occupation-5': 1, 'sex-M': 1}],
#  [467, {'age_group-35': 1, 'occupation-3': 1, 'sex-F': 1}],
#  [468, {'age_group-1': 1, 'occupation-10': 1, 'sex-F': 1}],
#  [469, {'age_group-35': 1, 'occupation-6': 1, 'sex-M': 1}],
#  [470, {'age_group-1': 1, 'occupation-10': 1, 'sex-F': 1}],
#  [471, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [472, {'age_group-35': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [473, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [474, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [475, {'age_group-25': 1, 'occupation-2': 1, 'sex-F': 1}],
#  [476, {'age_group-35': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [477, {'age_group-35': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [478, {'age_group-50': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [479, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [480, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [481, {'age_group-45': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [482, {'age_group-25': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [483, {'age_group-18': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [484, {'age_group-1': 1, 'occupation-10': 1, 'sex-F': 1}],
#  [485, {'age_group-56': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [486, {'age_group-56': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [487, {'age_group-35': 1, 'occupation-17': 1, 'sex-F': 1}],
#  [488, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [489, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [490, {'age_group-1': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [491, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [492, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [493, {'age_group-50': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [494, {'age_group-35': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [495, {'age_group-18': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [496, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [497, {'age_group-25': 1, 'occupation-17': 1, 'sex-F': 1}],
#  [498, {'age_group-35': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [499, {'age_group-25': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [500, {'age_group-18': 1, 'occupation-2': 1, 'sex-F': 1}],
#  [501, {'age_group-25': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [502, {'age_group-35': 1, 'occupation-6': 1, 'sex-M': 1}],
#  [503, {'age_group-35': 1, 'occupation-11': 1, 'sex-M': 1}],
#  [504, {'age_group-25': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [505, {'age_group-35': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [506, {'age_group-25': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [507, {'age_group-25': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [508, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [509, {'age_group-25': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [510, {'age_group-18': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [511, {'age_group-45': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [512, {'age_group-35': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [513, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [514, {'age_group-25': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [515, {'age_group-25': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [516, {'age_group-56': 1, 'occupation-14': 1, 'sex-F': 1}],
#  [517, {'age_group-25': 1, 'occupation-14': 1, 'sex-F': 1}],
#  [518, {'age_group-35': 1, 'occupation-12': 1, 'sex-F': 1}],
#  [519, {'age_group-35': 1, 'occupation-14': 1, 'sex-F': 1}],
#  [520, {'age_group-35': 1, 'occupation-20': 1, 'sex-F': 1}],
#  [521, {'age_group-56': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [522, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [523, {'age_group-50': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [524, {'age_group-18': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [525, {'age_group-35': 1, 'occupation-6': 1, 'sex-M': 1}],
#  [526, {'age_group-45': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [527, {'age_group-25': 1, 'occupation-2': 1, 'sex-F': 1}],
#  [528, {'age_group-18': 1, 'occupation-17': 1, 'sex-F': 1}],
#  [529, {'age_group-35': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [530, {'age_group-25': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [531, {'age_group-18': 1, 'occupation-14': 1, 'sex-F': 1}],
#  [532, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [533, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [534, {'age_group-25': 1, 'occupation-15': 1, 'sex-M': 1}],
#  [535, {'age_group-35': 1, 'occupation-6': 1, 'sex-M': 1}],
#  [536, {'age_group-25': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [537, {'age_group-45': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [538, {'age_group-56': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [539, {'age_group-25': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [540, {'age_group-18': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [541, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [542, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [543, {'age_group-25': 1, 'occupation-5': 1, 'sex-M': 1}],
#  [544, {'age_group-35': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [545, {'age_group-35': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [546, {'age_group-25': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [547, {'age_group-35': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [548, {'age_group-35': 1, 'occupation-16': 1, 'sex-F': 1}],
#  [549, {'age_group-25': 1, 'occupation-6': 1, 'sex-M': 1}],
#  [550, {'age_group-45': 1, 'occupation-8': 1, 'sex-M': 1}],
#  [551, {'age_group-35': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [552, {'age_group-50': 1, 'occupation-18': 1, 'sex-M': 1}],
#  [553, {'age_group-25': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [554, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [555, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [556, {'age_group-25': 1, 'occupation-9': 1, 'sex-F': 1}],
#  [557, {'age_group-56': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [558, {'age_group-35': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [559, {'age_group-25': 1, 'occupation-7': 1, 'sex-F': 1}],
#  [560, {'age_group-45': 1, 'occupation-15': 1, 'sex-M': 1}],
#  [561, {'age_group-18': 1, 'occupation-14': 1, 'sex-F': 1}],
#  [562, {'age_group-35': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [563, {'age_group-25': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [564, {'age_group-45': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [565, {'age_group-25': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [566, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [567, {'age_group-35': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [568, {'age_group-50': 1, 'occupation-17': 1, 'sex-F': 1}],
#  [569, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [570, {'age_group-25': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [571, {'age_group-50': 1, 'occupation-5': 1, 'sex-M': 1}],
#  [572, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [573, {'age_group-35': 1, 'occupation-2': 1, 'sex-F': 1}],
#  [574, {'age_group-25': 1, 'occupation-19': 1, 'sex-M': 1}],
#  [575, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [576, {'age_group-45': 1, 'occupation-15': 1, 'sex-F': 1}],
#  [577, {'age_group-35': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [578, {'age_group-18': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [579, {'age_group-25': 1, 'occupation-5': 1, 'sex-M': 1}],
#  [580, {'age_group-1': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [581, {'age_group-50': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [582, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [583, {'age_group-25': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [584, {'age_group-25': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [585, {'age_group-18': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [586, {'age_group-35': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [587, {'age_group-25': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [588, {'age_group-25': 1, 'occupation-11': 1, 'sex-F': 1}],
#  [589, {'age_group-18': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [590, {'age_group-35': 1, 'occupation-6': 1, 'sex-F': 1}],
#  [591, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [592, {'age_group-18': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [593, {'age_group-50': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [594, {'age_group-56': 1, 'occupation-13': 1, 'sex-F': 1}],
#  [595, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [596, {'age_group-25': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [597, {'age_group-35': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [598, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [599, {'age_group-50': 1, 'occupation-6': 1, 'sex-M': 1}],
#  [600, {'age_group-35': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [601, {'age_group-18': 1, 'occupation-20': 1, 'sex-F': 1}],
#  [602, {'age_group-56': 1, 'occupation-6': 1, 'sex-F': 1}],
#  [603, {'age_group-25': 1, 'occupation-6': 1, 'sex-F': 1}],
#  [604, {'age_group-45': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [605, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [606, {'age_group-1': 1, 'occupation-10': 1, 'sex-F': 1}],
#  [607, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [608, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [609, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [610, {'age_group-25': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [611, {'age_group-35': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [612, {'age_group-50': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [613, {'age_group-35': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [614, {'age_group-35': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [615, {'age_group-50': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [616, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [617, {'age_group-25': 1, 'occupation-7': 1, 'sex-F': 1}],
#  [618, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [619, {'age_group-18': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [620, {'age_group-18': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [621, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [622, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [623, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [624, {'age_group-25': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [625, {'age_group-35': 1, 'occupation-12': 1, 'sex-F': 1}],
#  [626, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [627, {'age_group-50': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [628, {'age_group-35': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [629, {'age_group-1': 1, 'occupation-10': 1, 'sex-F': 1}],
#  [630, {'age_group-35': 1, 'occupation-14': 1, 'sex-F': 1}],
#  [631, {'age_group-35': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [632, {'age_group-45': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [633, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [634, {'age_group-1': 1, 'occupation-10': 1, 'sex-F': 1}],
#  [635, {'age_group-56': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [636, {'age_group-18': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [637, {'age_group-35': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [638, {'age_group-25': 1, 'occupation-6': 1, 'sex-M': 1}],
#  [639, {'age_group-45': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [640, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [641, {'age_group-35': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [642, {'age_group-35': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [643, {'age_group-25': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [644, {'age_group-25': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [645, {'age_group-35': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [646, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [647, {'age_group-35': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [648, {'age_group-25': 1, 'occupation-12': 1, 'sex-F': 1}],
#  [649, {'age_group-25': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [650, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [651, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [652, {'age_group-18': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [653, {'age_group-56': 1, 'occupation-13': 1, 'sex-M': 1}],
#  [654, {'age_group-50': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [655, {'age_group-25': 1, 'occupation-2': 1, 'sex-F': 1}],
#  [656, {'age_group-45': 1, 'occupation-16': 1, 'sex-F': 1}],
#  [657, {'age_group-50': 1, 'occupation-13': 1, 'sex-F': 1}],
#  [658, {'age_group-25': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [659, {'age_group-25': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [660, {'age_group-45': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [661, {'age_group-45': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [662, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [663, {'age_group-25': 1, 'occupation-7': 1, 'sex-F': 1}],
#  [664, {'age_group-35': 1, 'occupation-18': 1, 'sex-M': 1}],
#  [665, {'age_group-18': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [666, {'age_group-18': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [667, {'age_group-25': 1, 'occupation-18': 1, 'sex-M': 1}],
#  [668, {'age_group-25': 1, 'occupation-3': 1, 'sex-F': 1}],
#  [669, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [670, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [671, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [672, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [673, {'age_group-25': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [674, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [675, {'age_group-25': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [676, {'age_group-18': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [677, {'age_group-50': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [678, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [679, {'age_group-35': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [680, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [681, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [682, {'age_group-25': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [683, {'age_group-25': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [684, {'age_group-25': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [685, {'age_group-25': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [686, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [687, {'age_group-25': 1, 'occupation-7': 1, 'sex-F': 1}],
#  [688, {'age_group-56': 1, 'occupation-13': 1, 'sex-M': 1}],
#  [689, {'age_group-50': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [690, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [691, {'age_group-35': 1, 'occupation-11': 1, 'sex-M': 1}],
#  [692, {'age_group-25': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [693, {'age_group-35': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [694, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [695, {'age_group-18': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [696, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [697, {'age_group-50': 1, 'occupation-6': 1, 'sex-F': 1}],
#  [698, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [699, {'age_group-18': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [700, {'age_group-50': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [701, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [702, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [703, {'age_group-56': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [704, {'age_group-35': 1, 'occupation-8': 1, 'sex-F': 1}],
#  [705, {'age_group-25': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [706, {'age_group-35': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [707, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [708, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [709, {'age_group-18': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [710, {'age_group-25': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [711, {'age_group-25': 1, 'occupation-18': 1, 'sex-M': 1}],
#  [712, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [713, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [714, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [715, {'age_group-18': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [716, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [717, {'age_group-25': 1, 'occupation-11': 1, 'sex-M': 1}],
#  [718, {'age_group-18': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [719, {'age_group-1': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [720, {'age_group-18': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [721, {'age_group-35': 1, 'occupation-9': 1, 'sex-F': 1}],
#  [722, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [723, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [724, {'age_group-50': 1, 'occupation-13': 1, 'sex-M': 1}],
#  [725, {'age_group-56': 1, 'occupation-11': 1, 'sex-M': 1}],
#  [726, {'age_group-25': 1, 'occupation-9': 1, 'sex-F': 1}],
#  [727, {'age_group-35': 1, 'occupation-11': 1, 'sex-M': 1}],
#  [728, {'age_group-25': 1, 'occupation-6': 1, 'sex-M': 1}],
#  [729, {'age_group-35': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [730, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [731, {'age_group-45': 1, 'occupation-3': 1, 'sex-M': 1}],
#  [732, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [733, {'age_group-35': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [734, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [735, {'age_group-25': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [736, {'age_group-18': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [737, {'age_group-1': 1, 'occupation-19': 1, 'sex-M': 1}],
#  [738, {'age_group-18': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [739, {'age_group-35': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [740, {'age_group-25': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [741, {'age_group-25': 1, 'occupation-5': 1, 'sex-M': 1}],
#  [742, {'age_group-18': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [743, {'age_group-1': 1, 'occupation-2': 1, 'sex-F': 1}],
#  [744, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [745, {'age_group-1': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [746, {'age_group-18': 1, 'occupation-19': 1, 'sex-F': 1}],
#  [747, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [748, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [749, {'age_group-35': 1, 'occupation-18': 1, 'sex-M': 1}],
#  [750, {'age_group-35': 1, 'occupation-9': 1, 'sex-F': 1}],
#  [751, {'age_group-25': 1, 'occupation-17': 1, 'sex-F': 1}],
#  [752, {'age_group-25': 1, 'occupation-3': 1, 'sex-F': 1}],
#  [753, {'age_group-1': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [754, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [755, {'age_group-35': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [756, {'age_group-35': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [757, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [758, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [759, {'age_group-56': 1, 'occupation-3': 1, 'sex-F': 1}],
#  [760, {'age_group-56': 1, 'occupation-15': 1, 'sex-M': 1}],
#  [761, {'age_group-18': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [762, {'age_group-1': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [763, {'age_group-18': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [764, {'age_group-18': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [765, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [766, {'age_group-25': 1, 'occupation-7': 1, 'sex-F': 1}],
#  [767, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [768, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [769, {'age_group-45': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [770, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [771, {'age_group-50': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [772, {'age_group-18': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [773, {'age_group-25': 1, 'occupation-6': 1, 'sex-M': 1}],
#  [774, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [775, {'age_group-1': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [776, {'age_group-25': 1, 'occupation-3': 1, 'sex-F': 1}],
#  [777, {'age_group-18': 1, 'occupation-19': 1, 'sex-M': 1}],
#  [778, {'age_group-18': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [779, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [780, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [781, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [782, {'age_group-56': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [783, {'age_group-25': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [784, {'age_group-18': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [785, {'age_group-18': 1, 'occupation-19': 1, 'sex-M': 1}],
#  [786, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [787, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [788, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [789, {'age_group-18': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [790, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [791, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [792, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [793, {'age_group-35': 1, 'occupation-14': 1, 'sex-F': 1}],
#  [794, {'age_group-50': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [795, {'age_group-35': 1, 'occupation-14': 1, 'sex-F': 1}],
#  [796, {'age_group-50': 1, 'occupation-6': 1, 'sex-M': 1}],
#  [797, {'age_group-50': 1, 'occupation-7': 1, 'sex-F': 1}],
#  [798, {'age_group-25': 1, 'occupation-20': 1, 'sex-F': 1}],
#  [799, {'age_group-25': 1, 'occupation-5': 1, 'sex-F': 1}],
#  [800, {'age_group-35': 1, 'occupation-12': 1, 'sex-F': 1}],
#  [801, {'age_group-25': 1, 'occupation-20': 1, 'sex-F': 1}],
#  [802, {'age_group-25': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [803, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [804, {'age_group-25': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [805, {'age_group-35': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [806, {'age_group-35': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [807, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [808, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [809, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [810, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [811, {'age_group-50': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [812, {'age_group-25': 1, 'occupation-6': 1, 'sex-M': 1}],
#  [813, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [814, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [815, {'age_group-25': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [816, {'age_group-45': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [817, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [818, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [819, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [820, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [821, {'age_group-18': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [822, {'age_group-25': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [823, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [824, {'age_group-35': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [825, {'age_group-56': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [826, {'age_group-35': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [827, {'age_group-45': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [828, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [829, {'age_group-1': 1, 'occupation-19': 1, 'sex-M': 1}],
#  [830, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [831, {'age_group-45': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [832, {'age_group-18': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [833, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [834, {'age_group-35': 1, 'occupation-12': 1, 'sex-F': 1}],
#  [835, {'age_group-56': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [836, {'age_group-25': 1, 'occupation-11': 1, 'sex-M': 1}],
#  [837, {'age_group-56': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [838, {'age_group-50': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [839, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [840, {'age_group-25': 1, 'occupation-3': 1, 'sex-F': 1}],
#  [841, {'age_group-50': 1, 'occupation-14': 1, 'sex-F': 1}],
#  [842, {'age_group-18': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [843, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [844, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [845, {'age_group-18': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [846, {'age_group-25': 1, 'occupation-5': 1, 'sex-M': 1}],
#  [847, {'age_group-25': 1, 'occupation-7': 1, 'sex-F': 1}],
#  [848, {'age_group-25': 1, 'occupation-15': 1, 'sex-M': 1}],
#  [849, {'age_group-25': 1, 'occupation-3': 1, 'sex-M': 1}],
#  [850, {'age_group-35': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [851, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [852, {'age_group-25': 1, 'occupation-5': 1, 'sex-M': 1}],
#  [853, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [854, {'age_group-25': 1, 'occupation-16': 1, 'sex-F': 1}],
#  [855, {'age_group-18': 1, 'occupation-2': 1, 'sex-F': 1}],
#  [856, {'age_group-45': 1, 'occupation-6': 1, 'sex-F': 1}],
#  [857, {'age_group-35': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [858, {'age_group-35': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [859, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [860, {'age_group-18': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [861, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [862, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [863, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [864, {'age_group-25': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [865, {'age_group-35': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [866, {'age_group-1': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [867, {'age_group-45': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [868, {'age_group-50': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [869, {'age_group-18': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [870, {'age_group-25': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [871, {'age_group-1': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [872, {'age_group-50': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [873, {'age_group-56': 1, 'occupation-6': 1, 'sex-M': 1}],
#  [874, {'age_group-45': 1, 'occupation-15': 1, 'sex-M': 1}],
#  [875, {'age_group-1': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [876, {'age_group-25': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [877, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [878, {'age_group-18': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [879, {'age_group-45': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [880, {'age_group-35': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [881, {'age_group-18': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [882, {'age_group-18': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [883, {'age_group-35': 1, 'occupation-14': 1, 'sex-F': 1}],
#  [884, {'age_group-1': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [885, {'age_group-35': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [886, {'age_group-56': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [887, {'age_group-56': 1, 'occupation-16': 1, 'sex-F': 1}],
#  [888, {'age_group-1': 1, 'occupation-10': 1, 'sex-F': 1}],
#  [889, {'age_group-45': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [890, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [891, {'age_group-25': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [892, {'age_group-35': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [893, {'age_group-50': 1, 'occupation-6': 1, 'sex-F': 1}],
#  [894, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [895, {'age_group-50': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [896, {'age_group-18': 1, 'occupation-15': 1, 'sex-M': 1}],
#  [897, {'age_group-25': 1, 'occupation-6': 1, 'sex-M': 1}],
#  [898, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [899, {'age_group-25': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [900, {'age_group-56': 1, 'occupation-13': 1, 'sex-F': 1}],
#  [901, {'age_group-56': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [902, {'age_group-56': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [903, {'age_group-56': 1, 'occupation-13': 1, 'sex-M': 1}],
#  [904, {'age_group-35': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [905, {'age_group-45': 1, 'occupation-12': 1, 'sex-F': 1}],
#  [906, {'age_group-1': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [907, {'age_group-45': 1, 'occupation-6': 1, 'sex-F': 1}],
#  [908, {'age_group-50': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [909, {'age_group-45': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [910, {'age_group-50': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [911, {'age_group-50': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [912, {'age_group-35': 1, 'occupation-2': 1, 'sex-F': 1}],
#  [913, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [914, {'age_group-35': 1, 'occupation-9': 1, 'sex-F': 1}],
#  [915, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [916, {'age_group-25': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [917, {'age_group-50': 1, 'occupation-6': 1, 'sex-M': 1}],
#  [918, {'age_group-45': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [919, {'age_group-35': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [920, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [921, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [922, {'age_group-56': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [923, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [924, {'age_group-50': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [925, {'age_group-35': 1, 'occupation-3': 1, 'sex-F': 1}],
#  [926, {'age_group-1': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [927, {'age_group-25': 1, 'occupation-20': 1, 'sex-F': 1}],
#  [928, {'age_group-56': 1, 'occupation-16': 1, 'sex-F': 1}],
#  [929, {'age_group-25': 1, 'occupation-15': 1, 'sex-M': 1}],
#  [930, {'age_group-25': 1, 'occupation-5': 1, 'sex-M': 1}],
#  [931, {'age_group-56': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [932, {'age_group-35': 1, 'occupation-6': 1, 'sex-F': 1}],
#  [933, {'age_group-45': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [934, {'age_group-35': 1, 'occupation-7': 1, 'sex-F': 1}],
#  [935, {'age_group-35': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [936, {'age_group-18': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [937, {'age_group-25': 1, 'occupation-15': 1, 'sex-M': 1}],
#  [938, {'age_group-25': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [939, {'age_group-25': 1, 'occupation-20': 1, 'sex-F': 1}],
#  [940, {'age_group-1': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [941, {'age_group-18': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [942, {'age_group-50': 1, 'occupation-6': 1, 'sex-F': 1}],
#  [943, {'age_group-45': 1, 'occupation-12': 1, 'sex-F': 1}],
#  [944, {'age_group-35': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [945, {'age_group-45': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [946, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [947, {'age_group-18': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [948, {'age_group-56': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [949, {'age_group-50': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [950, {'age_group-35': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [951, {'age_group-45': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [952, {'age_group-56': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [953, {'age_group-50': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [954, {'age_group-25': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [955, {'age_group-50': 1, 'occupation-7': 1, 'sex-F': 1}],
#  [956, {'age_group-35': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [957, {'age_group-35': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [958, {'age_group-35': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [959, {'age_group-50': 1, 'occupation-11': 1, 'sex-M': 1}],
#  [960, {'age_group-1': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [961, {'age_group-18': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [962, {'age_group-25': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [963, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [964, {'age_group-25': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [965, {'age_group-56': 1, 'occupation-7': 1, 'sex-M': 1}],
#  [966, {'age_group-56': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [967, {'age_group-18': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [968, {'age_group-50': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [969, {'age_group-25': 1, 'occupation-11': 1, 'sex-F': 1}],
#  [970, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [971, {'age_group-25': 1, 'occupation-12': 1, 'sex-M': 1}],
#  [972, {'age_group-45': 1, 'occupation-1': 1, 'sex-M': 1}],
#  [973, {'age_group-25': 1, 'occupation-1': 1, 'sex-F': 1}],
#  [974, {'age_group-35': 1, 'occupation-19': 1, 'sex-M': 1}],
#  [975, {'age_group-35': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [976, {'age_group-35': 1, 'occupation-14': 1, 'sex-M': 1}],
#  [977, {'age_group-25': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [978, {'age_group-18': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [979, {'age_group-1': 1, 'occupation-10': 1, 'sex-M': 1}],
#  [980, {'age_group-25': 1, 'occupation-6': 1, 'sex-M': 1}],
#  [981, {'age_group-25': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [982, {'age_group-25': 1, 'occupation-9': 1, 'sex-F': 1}],
#  [983, {'age_group-25': 1, 'occupation-16': 1, 'sex-F': 1}],
#  [984, {'age_group-50': 1, 'occupation-16': 1, 'sex-M': 1}],
#  [985, {'age_group-25': 1, 'occupation-4': 1, 'sex-M': 1}],
#  [986, {'age_group-56': 1, 'occupation-0': 1, 'sex-F': 1}],
#  [987, {'age_group-35': 1, 'occupation-17': 1, 'sex-F': 1}],
#  [988, {'age_group-50': 1, 'occupation-11': 1, 'sex-M': 1}],
#  [989, {'age_group-50': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [990, {'age_group-18': 1, 'occupation-6': 1, 'sex-M': 1}],
#  [991, {'age_group-25': 1, 'occupation-9': 1, 'sex-F': 1}],
#  [992, {'age_group-35': 1, 'occupation-3': 1, 'sex-F': 1}],
#  [993, {'age_group-25': 1, 'occupation-0': 1, 'sex-M': 1}],
#  [994, {'age_group-18': 1, 'occupation-2': 1, 'sex-M': 1}],
#  [995, {'age_group-18': 1, 'occupation-4': 1, 'sex-F': 1}],
#  [996, {'age_group-25': 1, 'occupation-17': 1, 'sex-M': 1}],
#  [997, {'age_group-1': 1, 'occupation-19': 1, 'sex-M': 1}],
#  [998, {'age_group-45': 1, 'occupation-20': 1, 'sex-M': 1}],
#  [999, {'age_group-25': 1, 'occupation-15': 1, 'sex-M': 1}],
#  [1000, {'age_group-25': 1, 'occupation-6': 1, 'sex-F': 1}],
#  ...]

# %%
# シーケンスをリスト化する関数
def flatten_sequences(sequences):
  sequences = [
    i if type(i) == list else [i] for i in sequences
  ]
  flattened = list(
    itertools.chain.from_iterable(sequences)
  )
  return flattened

# |で区切られた複数のジャンル情報をリスト化
df_item['genre'] = df_item['genres'].str.split('|')
df_item = df_item[df_item['item_id'].isin(uq_items)]
df_item['genre'] = df_item[['genre']].values.tolist()
df_item['genre'] = \
  df_item['genre'].apply(flatten_sequences)

# 各アイテムの特徴量を格納するリスト
uq_item_features = []
# アイテムの特徴量カラムとなる集合（重複なし）
set_item_features = set()

# 各アイテムに対してLightFM用の特徴量データを作成する
for row in df_item.itertuples():
  item_features = {}
  dict_row = []

  for s in row.genre:
    # 各アイテムの特徴量をone-hot化しリストとして持つ
    item_features[s] = 1
    # アイテム特徴量カラムに追加する
    set_item_features.add(s)

  # アイテムIDと特徴量をリストに格納する
  dict_row.append(row.item_id)
  dict_row.append(item_features)
  uq_item_features.append(dict_row)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
uq_item_features
# Out:
# [[1, {'Animation': 1, "Children's": 1, 'Comedy': 1}],
#  [2, {'Adventure': 1, "Children's": 1, 'Fantasy': 1}],
#  [3, {'Comedy': 1, 'Romance': 1}],
#  [4, {'Comedy': 1, 'Drama': 1}],
#  [5, {'Comedy': 1}],
#  [6, {'Action': 1, 'Crime': 1, 'Thriller': 1}],
#  [7, {'Comedy': 1, 'Romance': 1}],
#  [8, {'Adventure': 1, "Children's": 1}],
#  [9, {'Action': 1}],
#  [10, {'Action': 1, 'Adventure': 1, 'Thriller': 1}],
#  [11, {'Comedy': 1, 'Drama': 1, 'Romance': 1}],
#  [12, {'Comedy': 1, 'Horror': 1}],
#  [13, {'Animation': 1, "Children's": 1}],
#  [14, {'Drama': 1}],
#  [15, {'Action': 1, 'Adventure': 1, 'Romance': 1}],
#  [16, {'Drama': 1, 'Thriller': 1}],
#  [17, {'Drama': 1, 'Romance': 1}],
#  [18, {'Thriller': 1}],
#  [19, {'Comedy': 1}],
#  [20, {'Action': 1}],
#  [21, {'Action': 1, 'Comedy': 1, 'Drama': 1}],
#  [22, {'Crime': 1, 'Drama': 1, 'Thriller': 1}],
#  [23, {'Thriller': 1}],
#  [24, {'Drama': 1, 'Sci-Fi': 1}],
#  [25, {'Drama': 1, 'Romance': 1}],
#  [26, {'Drama': 1}],
#  [27, {'Drama': 1}],
#  [28, {'Romance': 1}],
#  [29, {'Adventure': 1, 'Sci-Fi': 1}],
#  [30, {'Drama': 1}],
#  [31, {'Drama': 1}],
#  [32, {'Drama': 1, 'Sci-Fi': 1}],
#  [33, {'Adventure': 1, 'Romance': 1}],
#  [34, {"Children's": 1, 'Comedy': 1, 'Drama': 1}],
#  [35, {'Drama': 1, 'Romance': 1}],
#  [36, {'Drama': 1}],
#  [37, {'Documentary': 1}],
#  [38, {'Comedy': 1}],
#  [39, {'Comedy': 1, 'Romance': 1}],
#  [40, {'Drama': 1}],
#  [41, {'Drama': 1, 'War': 1}],
#  [42, {'Action': 1, 'Crime': 1, 'Drama': 1}],
#  [43, {'Drama': 1}],
#  [44, {'Action': 1, 'Adventure': 1}],
#  [45, {'Comedy': 1, 'Drama': 1}],
#  [46, {'Drama': 1, 'Romance': 1}],
#  [47, {'Crime': 1, 'Thriller': 1}],
#  [48, {'Animation': 1, "Children's": 1, 'Musical': 1, 'Romance': 1}],
#  [49, {'Drama': 1, 'Romance': 1}],
#  [50, {'Crime': 1, 'Thriller': 1}],
#  [52, {'Comedy': 1}],
#  [53, {'Drama': 1}],
#  [54, {"Children's": 1, 'Comedy': 1}],
#  [55, {'Drama': 1}],
#  [56, {'Adventure': 1, "Children's": 1, 'Fantasy': 1}],
#  [57, {'Drama': 1}],
#  [58, {'Drama': 1, 'Romance': 1}],
#  [59, {'Drama': 1, 'Mystery': 1}],
#  [60, {'Adventure': 1, "Children's": 1, 'Fantasy': 1}],
#  [61, {'Drama': 1, 'Thriller': 1}],
#  [62, {'Drama': 1}],
#  [63, {'Comedy': 1}],
#  [64, {'Comedy': 1, 'Romance': 1}],
#  [65, {'Comedy': 1}],
#  [66, {'Sci-Fi': 1, 'Thriller': 1}],
#  [67, {'Drama': 1}],
#  [68, {'Comedy': 1, 'Romance': 1}],
#  [69, {'Comedy': 1}],
#  [70, {'Action': 1, 'Comedy': 1, 'Crime': 1, 'Horror': 1, 'Thriller': 1}],
#  [71, {'Action': 1}],
#  [72, {'Comedy': 1, 'Drama': 1}],
#  [73, {'Drama': 1, 'Musical': 1}],
#  [74, {'Drama': 1, 'Romance': 1}],
#  [75, {'Comedy': 1, 'Drama': 1}],
#  [76, {'Sci-Fi': 1, 'Thriller': 1}],
#  [77, {'Documentary': 1}],
#  [78, {'Drama': 1}],
#  [79, {'Drama': 1, 'Thriller': 1}],
#  [80, {'Drama': 1}],
#  [81, {'Crime': 1, 'Drama': 1, 'Romance': 1}],
#  [82, {'Drama': 1}],
#  [83, {'Drama': 1}],
#  [84, {'Comedy': 1, 'Drama': 1}],
#  [85, {'Drama': 1, 'Romance': 1}],
#  [86, {'Adventure': 1, 'Drama': 1}],
#  [87, {"Children's": 1, 'Comedy': 1}],
#  [88, {'Comedy': 1}],
#  [89, {'Action': 1, 'Thriller': 1}],
#  [90, {'Drama': 1}],
#  [92, {'Drama': 1, 'Thriller': 1}],
#  [93, {'Comedy': 1, 'Romance': 1}],
#  [94, {'Drama': 1}],
#  [95, {'Action': 1, 'Thriller': 1}],
#  [96, {'Comedy': 1}],
#  [97, {'Drama': 1}],
#  [98, {'Action': 1, 'Thriller': 1}],
#  [99, {'Documentary': 1}],
#  [100, {'Drama': 1, 'Thriller': 1}],
#  [101, {'Comedy': 1}],
#  [102, {'Comedy': 1}],
#  [103, {'Thriller': 1}],
#  [104, {'Comedy': 1}],
#  [105, {'Drama': 1, 'Romance': 1}],
#  [106, {'Comedy': 1, 'Drama': 1}],
#  [107, {'Adventure': 1, "Children's": 1, 'Comedy': 1, 'Musical': 1}],
#  [108, {'Documentary': 1}],
#  [110, {'Action': 1, 'Drama': 1, 'War': 1}],
#  [111, {'Drama': 1, 'Thriller': 1}],
#  [112, {'Action': 1, 'Adventure': 1, 'Crime': 1}],
#  [113, {'Drama': 1, 'Mystery': 1}],
#  [114, {'Drama': 1}],
#  [116, {'Documentary': 1}],
#  [117, {'Crime': 1}],
#  [118, {'Comedy': 1, 'Romance': 1}],
#  [119, {'Comedy': 1}],
#  [120, {'Drama': 1}],
#  [121, {'Drama': 1}],
#  [122, {'Comedy': 1, 'Romance': 1}],
#  [123, {'Drama': 1, 'Mystery': 1, 'Romance': 1}],
#  [124, {'Drama': 1}],
#  [125, {'Comedy': 1}],
#  [126, {'Adventure': 1, "Children's": 1, 'Fantasy': 1}],
#  [127, {'Drama': 1}],
#  [128, {'Documentary': 1}],
#  [129, {'Comedy': 1, 'Romance': 1}],
#  [130, {'Drama': 1}],
#  [131, {'Drama': 1, 'Romance': 1}],
#  [132, {'Thriller': 1}],
#  [133, {'Comedy': 1, 'Drama': 1}],
#  [134, {'Documentary': 1}],
#  [135, {'Comedy': 1}],
#  [136, {'Documentary': 1}],
#  [137, {'Documentary': 1}],
#  [138, {'Drama': 1}],
#  [139, {'Action': 1, 'Drama': 1}],
#  [140, {'Drama': 1, 'Romance': 1}],
#  [141, {'Comedy': 1}],
#  [142, {'Drama': 1}],
#  [144, {'Comedy': 1}],
#  [145, {'Action': 1}],
#  [146, {'Adventure': 1, "Children's": 1}],
#  [147, {'Drama': 1}],
#  [148, {'Drama': 1}],
#  [149, {'Crime': 1, 'Drama': 1, 'Thriller': 1}],
#  [150, {'Drama': 1}],
#  [151, {'Drama': 1, 'Romance': 1, 'War': 1}],
#  [152, {'Horror': 1}],
#  [153, {'Action': 1, 'Adventure': 1, 'Comedy': 1, 'Crime': 1}],
#  [154, {'Drama': 1}],
#  [155, {'Drama': 1, 'War': 1}],
#  [156, {'Comedy': 1}],
#  [157, {'Comedy': 1, 'War': 1}],
#  [158, {'Adventure': 1, "Children's": 1}],
#  [159, {'Drama': 1}],
#  [160, {'Action': 1, 'Adventure': 1, 'Mystery': 1, 'Sci-Fi': 1}],
#  [161, {'Drama': 1, 'Thriller': 1, 'War': 1}],
#  [162, {'Documentary': 1}],
#  [163, {'Action': 1, 'Romance': 1, 'Thriller': 1}],
#  [164, {'Crime': 1, 'Film-Noir': 1, 'Mystery': 1, 'Thriller': 1}],
#  [165, {'Action': 1, 'Thriller': 1}],
#  [166, {'Comedy': 1, 'Drama': 1}],
#  [167, {'Drama': 1}],
#  [168, {'Action': 1, 'Adventure': 1, 'Drama': 1, 'Romance': 1}],
#  [169, {'Adventure': 1, "Children's": 1, 'Drama': 1}],
#  [170, {'Action': 1, 'Crime': 1, 'Thriller': 1}],
#  [171, {'Comedy': 1}],
#  [172, {'Action': 1, 'Sci-Fi': 1, 'Thriller': 1}],
#  [173, {'Action': 1, 'Adventure': 1, 'Sci-Fi': 1}],
#  [174, {'Comedy': 1}],
#  [175, {'Drama': 1}],
#  [176, {'Comedy': 1}],
#  [177, {'Horror': 1}],
#  [178, {'Comedy': 1}],
#  [179, {'Drama': 1, 'Romance': 1}],
#  [180, {'Comedy': 1}],
#  [181, {'Action': 1, "Children's": 1}],
#  [182, {'Drama': 1, 'Romance': 1}],
#  [183, {'Thriller': 1}],
#  [184, {'Drama': 1}],
#  [185, {'Sci-Fi': 1, 'Thriller': 1}],
#  [186, {'Comedy': 1}],
#  [187, {'Comedy': 1}],
#  [188, {'Horror': 1}],
#  [189, {'Comedy': 1}],
#  [190, {'Thriller': 1}],
#  [191, {'Drama': 1}],
#  [192, {'Documentary': 1}],
#  [193, {'Drama': 1}],
#  [194, {'Drama': 1}],
#  [195, {'Comedy': 1, 'Drama': 1, 'Romance': 1}],
#  [196, {'Horror': 1, 'Sci-Fi': 1}],
#  [197, {'Drama': 1}],
#  [198, {'Action': 1, 'Crime': 1, 'Sci-Fi': 1}],
#  [199, {'Drama': 1, 'Musical': 1}],
#  [200, {'Thriller': 1}],
#  [201, {'Drama': 1}],
#  [202, {'Drama': 1, 'Romance': 1}],
#  [203, {'Comedy': 1}],
#  [204, {'Action': 1}],
#  [205, {'Comedy': 1, 'Drama': 1}],
#  [206, {'Documentary': 1}],
#  [207, {'Drama': 1, 'Romance': 1}],
#  [208, {'Action': 1, 'Adventure': 1}],
#  [209, {'Drama': 1}],
#  [210, {'Western': 1}],
#  [211, {'Drama': 1}],
#  [212, {'Comedy': 1}],
#  [213, {'Drama': 1}],
#  [214, {'Drama': 1}],
#  [215, {'Drama': 1, 'Romance': 1}],
#  [216, {'Comedy': 1}],
#  [217, {'Drama': 1, 'Thriller': 1}],
#  [218, {'Comedy': 1, 'Drama': 1}],
#  [219, {'Drama': 1}],
#  [220, {'Horror': 1}],
#  [222, {'Drama': 1, 'Romance': 1}],
#  [223, {'Comedy': 1}],
#  [224, {'Comedy': 1, 'Drama': 1, 'Romance': 1}],
#  [225, {'Drama': 1, 'Thriller': 1}],
#  [226, {'Thriller': 1}],
#  [227, {'Action': 1}],
#  [228, {'Comedy': 1}],
#  [229, {'Drama': 1, 'Thriller': 1}],
#  [230, {'Drama': 1, 'Thriller': 1}],
#  [231, {'Comedy': 1}],
#  [232, {'Comedy': 1, 'Drama': 1}],
#  [233, {'Drama': 1}],
#  [234, {'Comedy': 1}],
#  [235, {'Comedy': 1, 'Drama': 1}],
#  [236, {'Comedy': 1, 'Romance': 1}],
#  [237, {'Comedy': 1, 'Romance': 1}],
#  [238, {'Adventure': 1, "Children's": 1}],
#  [239, {'Animation': 1, "Children's": 1, 'Comedy': 1, 'Romance': 1}],
#  [240, {'Thriller': 1}],
#  [241, {"Children's": 1, 'Drama': 1}],
#  [242, {'Drama': 1, 'Musical': 1}],
#  [243, {'Comedy': 1}],
#  [244, {'Animation': 1, "Children's": 1}],
#  [245, {'Crime': 1, 'Drama': 1}],
#  [246, {'Documentary': 1}],
#  [247, {'Drama': 1, 'Fantasy': 1, 'Romance': 1, 'Thriller': 1}],
#  [248, {'Comedy': 1}],
#  [249, {'Drama': 1, 'Romance': 1}],
#  [250, {"Children's": 1, 'Comedy': 1}],
#  [251, {'Action': 1}],
#  [252, {'Comedy': 1, 'Romance': 1}],
#  [253, {'Drama': 1, 'Horror': 1}],
#  [254, {'Drama': 1}],
#  [255, {'Comedy': 1}],
#  [256, {'Comedy': 1, 'Sci-Fi': 1}],
#  [257, {'Mystery': 1, 'Thriller': 1}],
#  [258,
#   {'Adventure': 1, "Children's": 1, 'Comedy': 1, 'Fantasy': 1, 'Romance': 1}],
#  [259, {'Crime': 1, 'Drama': 1, 'Thriller': 1}],
#  [260, {'Action': 1, 'Adventure': 1, 'Fantasy': 1, 'Sci-Fi': 1}],
#  [261, {'Drama': 1}],
#  [262, {"Children's": 1, 'Drama': 1}],
#  [263, {'Drama': 1}],
#  [264, {'Drama': 1}],
#  [265, {'Drama': 1, 'Romance': 1}],
#  [266, {'Drama': 1, 'Romance': 1, 'War': 1, 'Western': 1}],
#  [267, {'Comedy': 1}],
#  [268, {'Drama': 1}],
#  [269, {'Drama': 1}],
#  [270, {'Drama': 1, 'Romance': 1}],
#  [271, {'Drama': 1}],
#  [272, {'Drama': 1}],
#  [273, {'Drama': 1, 'Horror': 1}],
#  [274, {'Comedy': 1}],
#  [275, {'Comedy': 1}],
#  [276, {'Comedy': 1, 'Romance': 1}],
#  [277, {'Drama': 1}],
#  [278, {'Comedy': 1}],
#  [279, {'Drama': 1}],
#  [280, {'Drama': 1, 'Thriller': 1}],
#  [281, {'Drama': 1}],
#  [282, {'Drama': 1}],
#  [283, {'Crime': 1, 'Drama': 1}],
#  [286, {'Action': 1, 'Sci-Fi': 1, 'Thriller': 1}],
#  [287, {'Comedy': 1, 'Romance': 1}],
#  [288, {'Action': 1, 'Thriller': 1}],
#  [289, {'Comedy': 1, 'Romance': 1}],
#  [290, {'Crime': 1, 'Drama': 1}],
#  [291, {'Thriller': 1}],
#  [292, {'Action': 1, 'Drama': 1, 'Thriller': 1}],
#  [293, {'Crime': 1, 'Drama': 1, 'Romance': 1, 'Thriller': 1}],
#  [294, {'Comedy': 1, 'Romance': 1}],
#  [295, {'Comedy': 1, 'Romance': 1}],
#  [296, {'Crime': 1, 'Drama': 1}],
#  [297, {'Drama': 1}],
#  [298, {'Comedy': 1}],
#  [299, {'Drama': 1}],
#  [300, {'Drama': 1}],
#  [301, {'Drama': 1, 'Romance': 1}],
#  [302, {'Drama': 1, 'Romance': 1}],
#  [303, {'Action': 1, 'Adventure': 1, 'Western': 1}],
#  [304, {'Comedy': 1, 'Drama': 1}],
#  [305, {'Comedy': 1}],
#  [306, {'Drama': 1}],
#  [307, {'Drama': 1}],
#  [308, {'Drama': 1}],
#  [309, {'Drama': 1}],
#  [310, {'Comedy': 1}],
#  [311, {'Horror': 1, 'Thriller': 1}],
#  [312, {'Comedy': 1}],
#  [313, {'Animation': 1, "Children's": 1}],
#  [314, {'Drama': 1}],
#  [315, {'Action': 1}],
#  [316, {'Action': 1, 'Adventure': 1, 'Sci-Fi': 1}],
#  [317, {"Children's": 1, 'Comedy': 1, 'Fantasy': 1}],
#  [318, {'Drama': 1}],
#  [319, {'Thriller': 1}],
#  [320, {'Film-Noir': 1, 'Thriller': 1}],
#  [321, {'Drama': 1}],
#  [322, {'Comedy': 1, 'Drama': 1}],
#  [324, {'Comedy': 1}],
#  [325, {'Comedy': 1}],
#  [326, {'Drama': 1}],
#  [327, {'Action': 1, 'Comedy': 1, 'Musical': 1, 'Sci-Fi': 1}],
#  [328, {'Horror': 1}],
#  [329, {'Action': 1, 'Adventure': 1, 'Sci-Fi': 1}],
#  [330, {'Comedy': 1, 'Horror': 1}],
#  [331, {'Drama': 1}],
#  [332, {'Horror': 1, 'Sci-Fi': 1}],
#  [333, {'Comedy': 1}],
#  [334, {'Drama': 1}],
#  [335, {'Mystery': 1, 'Thriller': 1}],
#  [336, {'Drama': 1, 'War': 1}],
#  [337, {'Drama': 1}],
#  [338, {'Sci-Fi': 1, 'Thriller': 1}],
#  [339, {'Comedy': 1, 'Romance': 1}],
#  [340, {'Adventure': 1, 'Drama': 1}],
#  [341, {'Drama': 1}],
#  [342, {'Comedy': 1, 'Romance': 1}],
#  [343, {"Children's": 1}],
#  [344, {'Comedy': 1}],
#  [345, {'Comedy': 1, 'Drama': 1}],
#  [346, {'Drama': 1, 'Musical': 1}],
#  [347, {'Drama': 1}],
#  [348, {'Comedy': 1}],
#  [349, {'Action': 1, 'Adventure': 1, 'Thriller': 1}],
#  [350, {'Drama': 1, 'Mystery': 1, 'Thriller': 1}],
#  [351, {'Comedy': 1, 'Drama': 1, 'Romance': 1}],
#  [352, {'Comedy': 1}],
#  [353, {'Action': 1, 'Romance': 1, 'Thriller': 1}],
#  [354, {'Drama': 1}],
#  [355, {"Children's": 1, 'Comedy': 1}],
#  [356, {'Comedy': 1, 'Romance': 1, 'War': 1}],
#  [357, {'Comedy': 1, 'Romance': 1}],
#  [358, {'Drama': 1}],
#  [359, {'Comedy': 1, 'Drama': 1, 'Romance': 1}],
#  [360, {'Action': 1, 'Comedy': 1}],
#  [361, {'Drama': 1, 'Romance': 1}],
#  [362, {'Adventure': 1, "Children's": 1, 'Romance': 1}],
#  [363, {'Documentary': 1}],
#  [364, {'Animation': 1, "Children's": 1, 'Musical': 1}],
#  [365, {'Drama': 1}],
#  [366, {'Horror': 1}],
#  [367, {'Comedy': 1, 'Crime': 1, 'Fantasy': 1}],
#  [368, {'Action': 1, 'Comedy': 1, 'Western': 1}],
#  [369, {'Drama': 1}],
#  [370, {'Comedy': 1}],
#  [371, {'Comedy': 1, 'Drama': 1}],
#  [372, {'Comedy': 1, 'Drama': 1}],
#  [373, {'Thriller': 1}],
#  [374, {"Children's": 1, 'Comedy': 1}],
#  [375, {'Drama': 1}],
#  [376, {'Action': 1, 'Thriller': 1}],
#  [377, {'Action': 1, 'Romance': 1, 'Thriller': 1}],
#  [378, {'Comedy': 1, 'Romance': 1}],
#  [379, {'Action': 1, 'Sci-Fi': 1}],
#  [380, {'Action': 1, 'Adventure': 1, 'Comedy': 1, 'Romance': 1}],
#  [381, {'Drama': 1}],
#  [382, {'Drama': 1, 'Horror': 1}],
#  [383, {'Western': 1}],
#  [384, {'Action': 1}],
#  [385, {'Drama': 1}],
#  [386, {'Drama': 1}],
#  [387, {'Action': 1, 'Comedy': 1}],
#  [388, {'Drama': 1}],
#  [389, {'Drama': 1, 'Romance': 1, 'War': 1}],
#  [390, {'Action': 1, 'Comedy': 1, 'Drama': 1}],
#  [391, {'Crime': 1, 'Drama': 1}],
#  [392, {'Adventure': 1, "Children's": 1}],
#  [393, {'Action': 1}],
#  [394, {'Action': 1}],
#  [396, {'Drama': 1}],
#  [397, {'Horror': 1}],
#  [398, {'Documentary': 1}],
#  [401, {'Action': 1, 'Thriller': 1}],
#  [402, {'Comedy': 1}],
#  [404, {'Documentary': 1}],
#  [405, {'Action': 1, 'Sci-Fi': 1}],
#  [406, {'Drama': 1}],
#  [407, {'Horror': 1, 'Thriller': 1}],
#  [408, {'Drama': 1}],
#  [409, {'Drama': 1}],
#  [410, {'Comedy': 1}],
#  [411, {'Comedy': 1}],
#  [412, {'Drama': 1}],
#  [413, {'Comedy': 1}],
#  [414, {'Comedy': 1}],
#  [415, {'Comedy': 1, 'Thriller': 1}],
#  [416, {'Western': 1}],
#  [417, {'Comedy': 1, 'Romance': 1}],
#  [418, {'Drama': 1}],
#  [419, {'Comedy': 1}],
#  [420, {'Action': 1, 'Comedy': 1}],
#  [421, {'Adventure': 1, "Children's": 1}],
#  [422, {'Thriller': 1}],
#  [423, {'Action': 1, 'Thriller': 1}],
#  [424, {'Drama': 1}],
#  [425, {'Drama': 1, 'Romance': 1}],
#  [426, {'Horror': 1, 'Sci-Fi': 1, 'Thriller': 1}],
#  [427, {'Mystery': 1, 'Romance': 1, 'Thriller': 1}],
#  [428, {'Drama': 1}],
#  [429, {'Comedy': 1}],
#  [430, {'Drama': 1}],
#  [431, {'Crime': 1, 'Drama': 1}],
#  [432, {'Comedy': 1, 'Western': 1}],
#  [433, {'Comedy': 1}],
#  [434, {'Action': 1, 'Adventure': 1, 'Crime': 1}],
#  [435, {'Comedy': 1, 'Sci-Fi': 1}],
#  [436, {'Drama': 1, 'Thriller': 1}],
#  [437, {'Comedy': 1}],
#  [438, {'Action': 1, 'Comedy': 1}],
#  [439, {'Drama': 1}],
#  [440, {'Comedy': 1, 'Romance': 1}],
#  [441, {'Comedy': 1}],
#  [442, {'Action': 1, 'Sci-Fi': 1}],
#  [443, {'Documentary': 1}],
#  [444, {'Comedy': 1, 'Romance': 1}],
#  [445, {'Comedy': 1}],
#  [446, {'Drama': 1, 'Romance': 1}],
#  [447, {'Comedy': 1, 'Romance': 1}],
#  [448, {'Drama': 1}],
#  [449, {'Comedy': 1}],
#  [450, {'Comedy': 1, 'Drama': 1}],
#  [451, {'Drama': 1, 'Mystery': 1, 'Romance': 1}],
#  [452, {'Drama': 1}],
#  [453, {'Comedy': 1}],
#  [454, {'Drama': 1, 'Thriller': 1}],
#  [455, {'Adventure': 1, "Children's": 1, 'Drama': 1}],
#  [456, {'Drama': 1}],
#  [457, {'Action': 1, 'Thriller': 1}],
#  [458, {'Drama': 1, 'Western': 1}],
#  [459, {'Action': 1}],
#  [460, {'Comedy': 1}],
#  [461, {'Drama': 1, 'Romance': 1}],
#  [462, {'Action': 1, 'Adventure': 1}],
#  [463, {'Crime': 1, 'Drama': 1, 'Thriller': 1}],
#  [464, {'Action': 1, 'Adventure': 1, 'Crime': 1, 'Thriller': 1}],
#  [465, {'Action': 1, 'Drama': 1, 'War': 1}],
#  [466, {'Action': 1, 'Comedy': 1, 'War': 1}],
#  [467, {'Comedy': 1}],
#  [468, {'Comedy': 1, 'Romance': 1}],
#  [469, {'Drama': 1, 'Romance': 1}],
#  [470, {'Comedy': 1}],
#  [471, {'Comedy': 1, 'Romance': 1}],
#  [472, {'Comedy': 1, 'Drama': 1}],
#  [473, {'Comedy': 1, 'War': 1}],
#  [474, {'Action': 1, 'Thriller': 1}],
#  [475, {'Drama': 1}],
#  [476, {'Comedy': 1, 'Drama': 1}],
#  [477, {'Drama': 1}],
#  [478, {'Comedy': 1}],
#  [479, {'Action': 1}],
#  [480, {'Action': 1, 'Adventure': 1, 'Sci-Fi': 1}],
#  [481, {'Drama': 1, 'Thriller': 1}],
#  [482, {'Thriller': 1}],
#  [483, {'Drama': 1}],
#  [484, {'Adventure': 1, "Children's": 1}],
#  [485, {'Action': 1, 'Comedy': 1}],
#  [486, {'Comedy': 1}],
#  [487, {'Comedy': 1, 'Western': 1}],
#  [488, {'Drama': 1}],
#  [489, {'Comedy': 1}],
#  [490, {'Thriller': 1}],
#  [491, {'Drama': 1}],
#  [492, {'Comedy': 1, 'Mystery': 1}],
#  [493, {'Action': 1, 'Crime': 1, 'Drama': 1}],
#  [494, {'Action': 1, 'Thriller': 1}],
#  [495, {'Drama': 1}],
#  [496, {'Comedy': 1, 'Drama': 1, 'Romance': 1}],
#  [497, {'Comedy': 1, 'Romance': 1}],
#  [498, {'Drama': 1, 'Romance': 1}],
#  [499, {'Comedy': 1, 'Romance': 1}],
#  [500, {'Comedy': 1}],
#  [501, {'Drama': 1}],
#  [502, {'Action': 1, "Children's": 1}],
#  [503, {'Drama': 1}],
#  [504, {'Action': 1, 'Sci-Fi': 1}],
#  [505, {'Comedy': 1}],
#  [506, {'Drama': 1}],
#  [507, {'Action': 1, 'Drama': 1}],
#  [508, {'Drama': 1}],
#  [509, {'Drama': 1, 'Romance': 1}],
#  [510, {'Drama': 1}],
#  [511, {'Action': 1, 'Drama': 1}],
#  [512, {'Horror': 1, 'Sci-Fi': 1}],
#  [513, {'Comedy': 1, 'Mystery': 1, 'Romance': 1}],
#  [514, {'Comedy': 1}],
#  [515, {'Drama': 1}],
#  [516, {'Comedy': 1, 'Drama': 1, 'War': 1}],
#  [517, {'Action': 1, 'Drama': 1, 'Mystery': 1}],
#  [518, {'Comedy': 1}],
#  [519, {'Sci-Fi': 1, 'Thriller': 1}],
#  [520, {'Comedy': 1}],
#  [521, {'Crime': 1, 'Thriller': 1}],
#  [522, {'Action': 1, 'Drama': 1}],
#  [523, {'Drama': 1}],
#  [524, {'Drama': 1}],
#  [525, {'Drama': 1}],
#  [526, {'Drama': 1}],
#  [527, {'Drama': 1, 'War': 1}],
#  [528, {'Drama': 1}],
#  [529, {'Drama': 1}],
#  [530, {'Drama': 1}],
#  [531, {"Children's": 1, 'Drama': 1}],
#  [532, {'Comedy': 1, 'Crime': 1, 'Horror': 1}],
#  [533, {'Action': 1}],
#  [534, {'Drama': 1, 'Romance': 1}],
#  [535, {'Drama': 1}],
#  [536, {'Drama': 1}],
#  [537, {'Comedy': 1, 'Drama': 1}],
#  [538, {'Drama': 1}],
#  [539, {'Comedy': 1, 'Romance': 1}],
#  [540, {'Thriller': 1}],
#  [541, {'Film-Noir': 1, 'Sci-Fi': 1}],
#  [542, {'Comedy': 1}],
#  [543, {'Comedy': 1, 'Romance': 1, 'Thriller': 1}],
#  [544, {'Action': 1}],
#  [545, {'Drama': 1}],
#  [546, {'Action': 1, 'Adventure': 1, "Children's": 1, 'Sci-Fi': 1}],
#  [547, {'Action': 1, 'Adventure': 1, 'Thriller': 1}],
#  [548, {'Action': 1}],
#  [549, {'Documentary': 1}],
#  [550, {'Comedy': 1, 'Romance': 1}],
#  [551, {"Children's": 1, 'Comedy': 1, 'Musical': 1}],
#  [552, {'Action': 1, 'Adventure': 1, 'Comedy': 1}],
#  [553, {'Western': 1}],
#  [554, {'Thriller': 1}],
#  [555, {'Action': 1, 'Crime': 1, 'Romance': 1}],
#  [556, {'Documentary': 1}],
#  [557, {'Drama': 1}],
#  [558,
#   {'Action': 1,
#    'Adventure': 1,
#    'Animation': 1,
#    "Children's": 1,
#    'Fantasy': 1}],
#  [559, {'Comedy': 1}],
#  [560, {'Drama': 1}],
#  [561, {'Thriller': 1}],
#  [562, {'Comedy': 1, 'Drama': 1}],
#  [563, {'Drama': 1}],
#  [564, {'Comedy': 1}],
#  [565, {'Horror': 1}],
#  [566, {'Comedy': 1, 'Romance': 1}],
#  [567, {'Drama': 1}],
#  [568, {'Comedy': 1, 'Drama': 1}],
#  [569, {"Children's": 1, 'Comedy': 1}],
#  [570, {'Comedy': 1, 'Drama': 1}],
#  [571, {'Drama': 1}],
#  [572, {'Drama': 1}],
#  [573, {'Drama': 1}],
#  [574, {'Comedy': 1, 'Drama': 1}],
#  [575, {"Children's": 1, 'Comedy': 1}],
#  [576, {'Comedy': 1}],
#  [577, {'Adventure': 1, "Children's": 1}],
#  [578, {'Drama': 1, 'Mystery': 1}],
#  [579, {'Thriller': 1}],
#  [580, {'Drama': 1}],
#  [581, {'Documentary': 1}],
#  [582, {'Comedy': 1}],
#  [583, {'Comedy': 1, 'Drama': 1}],
#  [584, {'Drama': 1}],
#  [585, {'Comedy': 1}],
#  [586, {"Children's": 1, 'Comedy': 1}],
#  [587, {'Comedy': 1, 'Romance': 1, 'Thriller': 1}],
#  [588, {'Animation': 1, "Children's": 1, 'Comedy': 1, 'Musical': 1}],
#  [589, {'Action': 1, 'Sci-Fi': 1, 'Thriller': 1}],
#  [590, {'Adventure': 1, 'Drama': 1, 'Western': 1}],
#  [591, {'Action': 1, 'Drama': 1, 'Thriller': 1}],
#  [592, {'Action': 1, 'Adventure': 1, 'Crime': 1, 'Drama': 1}],
#  [593, {'Drama': 1, 'Thriller': 1}],
#  [594, {'Animation': 1, "Children's": 1, 'Musical': 1}],
#  [595, {'Animation': 1, "Children's": 1, 'Musical': 1}],
#  [596, {'Animation': 1, "Children's": 1}],
#  [597, {'Comedy': 1, 'Romance': 1}],
#  [598, {'Comedy': 1}],
#  [599, {'Western': 1}],
#  [600, {'Thriller': 1}],
#  [601, {'Drama': 1}],
#  [602, {'Documentary': 1}],
#  [603, {'Comedy': 1}],
#  [605, {'Drama': 1, 'Romance': 1}],
#  [606, {'Horror': 1}],
#  [607, {'Drama': 1}],
#  [608, {'Crime': 1, 'Drama': 1, 'Thriller': 1}],
#  [609, {'Adventure': 1, "Children's": 1}],
#  [610,
#   {'Action': 1, 'Adventure': 1, 'Animation': 1, 'Horror': 1, 'Sci-Fi': 1}],
#  [611, {'Action': 1, 'Horror': 1, 'Sci-Fi': 1}],
#  [612, {'Comedy': 1}],
#  [613, {'Drama': 1, 'Romance': 1}],
#  [614, {'Drama': 1, 'Thriller': 1}],
#  [615, {'Drama': 1}],
#  [616, {'Animation': 1, "Children's": 1}],
#  [617, {'Drama': 1}],
#  [618, {'Comedy': 1, 'Romance': 1}],
#  [619, {'Comedy': 1}],
#  [621, {'Drama': 1}],
#  [623, {'Romance': 1}],
#  [624, {'Action': 1, 'Drama': 1, 'Thriller': 1}],
#  [626, {'Comedy': 1}],
#  [627, {'Drama': 1, 'Thriller': 1}],
#  [628, {'Drama': 1, 'Thriller': 1}],
#  [630, {'Drama': 1, 'Romance': 1}],
#  [631, {'Animation': 1, "Children's": 1, 'Musical': 1}],
#  [632, {'War': 1}],
#  [633, {'Comedy': 1}],
#  [634, {'Comedy': 1}],
#  [635, {'Comedy': 1, 'Drama': 1}],
#  [637, {'Comedy': 1}],
#  [638, {'Romance': 1}],
#  [639, {'Comedy': 1}],
#  [640, {'Drama': 1, 'Thriller': 1}],
#  [641, {'Comedy': 1}],
#  [642, {'Drama': 1}],
#  [643, {'Comedy': 1}],
#  [644, {'Comedy': 1}],
#  [645, {'Drama': 1}],
#  [647, {'Drama': 1, 'War': 1}],
#  [648, {'Action': 1, 'Adventure': 1, 'Mystery': 1}],
#  [649, {'Comedy': 1, 'Drama': 1}],
#  [650, {'Drama': 1}],
#  [651, {'Comedy': 1}],
#  [652, {'Mystery': 1}],
#  [653, {'Action': 1, 'Adventure': 1, 'Fantasy': 1}],
#  [655, {'Comedy': 1}],
#  [656, {'Comedy': 1}],
#  [657, {'Comedy': 1, 'Drama': 1}],
#  [658, {'Drama': 1}],
#  [659, {'Crime': 1, 'Thriller': 1}],
#  [660, {'Drama': 1}],
#  [661, {'Animation': 1, "Children's": 1, 'Musical': 1}],
#  [662, {'Thriller': 1}],
#  [663, {'Comedy': 1}],
#  [664, {'Comedy': 1}],
#  [665, {'War': 1}],
#  [666, {'Drama': 1}],
#  [667, {'Action': 1}],
#  [668, {'Drama': 1}],
#  [669, {'Drama': 1}],
#  [670, {'Drama': 1}],
#  [671, {'Comedy': 1, 'Sci-Fi': 1}],
#  [672, {'Drama': 1}],
#  [673,
#   {'Adventure': 1,
#    'Animation': 1,
#    "Children's": 1,
#    'Comedy': 1,
#    'Fantasy': 1}],
#  [674, {'Adventure': 1, 'Sci-Fi': 1}],
#  [678, {'Drama': 1, 'Thriller': 1}],
#  [679, {'Drama': 1}],
#  [680, {'Sci-Fi': 1}],
#  [681, {'Crime': 1}],
#  [682, {'Documentary': 1, 'Drama': 1}],
#  [684, {'Drama': 1}],
#  [685, {'Drama': 1}],
#  [687, {'Drama': 1, 'Romance': 1}],
#  [688, {'Action': 1, 'Adventure': 1, 'Comedy': 1, 'War': 1}],
#  [690, {'Romance': 1}],
#  [691, {'Comedy': 1, 'Romance': 1}],
#  [692, {'Action': 1, 'Sci-Fi': 1, 'Thriller': 1}],
#  [694, {'Action': 1}],
#  [695, {'Mystery': 1, 'Thriller': 1}],
#  [696, {'Thriller': 1}],
#  [697, {'Drama': 1, 'Romance': 1}],
#  [698, {'Drama': 1}],
#  [700, {'Comedy': 1}],
#  [701, {'Drama': 1}],
#  [702, {'Drama': 1}],
#  [703, {'Drama': 1}],
#  [704, {'Action': 1, 'Adventure': 1}],
#  [705, {'Comedy': 1}],
#  [706, {'Drama': 1}],
#  [707, {'Crime': 1, 'Film-Noir': 1, 'Thriller': 1}],
#  [708, {'Comedy': 1, 'Romance': 1}],
#  [709, {'Animation': 1, "Children's": 1}],
#  [710, {'Comedy': 1}],
#  [711, {'Adventure': 1, "Children's": 1}],
#  [712, {'Drama': 1}],
#  [714, {'Western': 1}],
#  [715, {'Drama': 1}],
#  [716, {'Crime': 1}],
#  [717, {'Comedy': 1}],
#  [718, {'Comedy': 1, 'Sci-Fi': 1}],
#  [719, {'Comedy': 1}],
#  [720, {'Animation': 1}],
#  [722, {'Documentary': 1}],
#  [724, {'Drama': 1, 'Horror': 1}],
#  [725, {'Comedy': 1}],
#  [726, {'Drama': 1}],
#  [728, {'Comedy': 1}],
#  [729, {'Drama': 1}],
#  [730, {'Drama': 1}],
#  [731, {'Mystery': 1, 'Thriller': 1}],
#  [732, {'Crime': 1}],
#  [733, {'Action': 1, 'Adventure': 1, 'Thriller': 1}],
#  [734, {'Comedy': 1}],
#  [735, {'Comedy': 1, 'Horror': 1}],
#  [736, {'Action': 1, 'Adventure': 1, 'Romance': 1, 'Thriller': 1}],
#  [737, {'Action': 1, 'Sci-Fi': 1}],
#  [741, {'Animation': 1, 'Sci-Fi': 1}],
#  [742, {'Horror': 1, 'Thriller': 1}],
#  [743, {'Comedy': 1}],
#  [744, {'Drama': 1}],
#  [745, {'Animation': 1, 'Comedy': 1, 'Thriller': 1}],
#  [746, {'Film-Noir': 1}],
#  [747, {'Comedy': 1}],
#  [748, {'Action': 1, 'Sci-Fi': 1, 'Thriller': 1}],
#  [749, {'Drama': 1}],
#  [750, {'Sci-Fi': 1, 'War': 1}],
#  [751, {'Comedy': 1}],
#  [753, {'Comedy': 1, 'Drama': 1}],
#  [754, {'Adventure': 1, "Children's": 1}],
#  [755, {"Children's": 1, 'Drama': 1}],
#  [756, {'Documentary': 1}],
#  [757, {'Drama': 1}],
#  [758, {'Drama': 1}],
#  [759, {'Documentary': 1}],
#  [760, {'War': 1}],
#  [761, {'Adventure': 1}],
#  [762, {'Comedy': 1, 'Crime': 1}],
#  [763, {'Drama': 1}],
#  [764, {'Drama': 1, 'Romance': 1}],
#  [765, {'Comedy': 1, 'Drama': 1}],
#  [766, {'Drama': 1}],
#  [767, {'Drama': 1}],
#  [769, {'Documentary': 1}],
#  [771, {'Comedy': 1, 'Drama': 1}],
#  [774, {'Drama': 1}],
#  [775, {'Horror': 1}],
#  [776, {'Comedy': 1, 'Drama': 1}],
#  [778, {'Drama': 1}],
#  [779, {'Drama': 1, 'Romance': 1}],
#  [780, {'Action': 1, 'Sci-Fi': 1, 'War': 1}],
#  [781, {'Drama': 1}],
#  [782, {'Thriller': 1}],
#  [783, {'Animation': 1, "Children's": 1, 'Musical': 1}],
#  [784, {'Comedy': 1}],
#  [785, {'Comedy': 1}],
#  [786, {'Action': 1, 'Thriller': 1}],
#  [787, {'Documentary': 1}],
#  [788, {'Comedy': 1, 'Fantasy': 1, 'Romance': 1, 'Sci-Fi': 1}],
#  [789, {'Drama': 1}],
#  [790, {'Drama': 1}],
#  [791, {'Documentary': 1}],
#  [792, {'Fantasy': 1}],
#  [793, {'Drama': 1}],
#  [796, {'Drama': 1}],
#  [798, {'Action': 1, 'Adventure': 1, 'Thriller': 1}],
#  [799, {'Comedy': 1, 'Horror': 1}],
#  [800, {'Drama': 1, 'Mystery': 1}],
#  [801, {"Children's": 1, 'Comedy': 1}],
#  [802, {'Drama': 1, 'Romance': 1}],
#  [803, {'Romance': 1}],
#  [804, {'Comedy': 1, 'Romance': 1}],
#  [805, {'Drama': 1}],
#  [806, {'Drama': 1}],
#  [807, {'Comedy': 1, 'Romance': 1}],
#  [808, {'Adventure': 1, "Children's": 1}],
#  [809, {'Action': 1, 'Adventure': 1}],
#  [810, {"Children's": 1, 'Comedy': 1, 'Fantasy': 1}],
#  [811, {'Comedy': 1}],
#  [813, {'Comedy': 1}],
#  [814, {'Drama': 1}],
#  [815, {'Action': 1, 'Mystery': 1, 'Thriller': 1}],
#  [818, {'Comedy': 1}],
#  [820, {'Drama': 1}],
#  [821, {'Romance': 1}],
#  [823, {'Drama': 1}],
#  [824, {'Drama': 1}],
#  [826, {'Drama': 1}],
#  [827, {'Drama': 1}],
#  [828, {'Adventure': 1, "Children's": 1}],
#  [829, {'Comedy': 1, 'Musical': 1}],
#  [830, {'Comedy': 1}],
#  [831, {'Drama': 1}],
#  [832, {'Drama': 1, 'Thriller': 1}],
#  [833, {'Comedy': 1}],
#  [834, {'Comedy': 1}],
#  [835, {'Drama': 1}],
#  [836, {'Action': 1, 'Adventure': 1, 'Thriller': 1}],
#  [837, {"Children's": 1, 'Comedy': 1}],
#  [838, {'Comedy': 1, 'Drama': 1, 'Romance': 1}],
#  [839, {'Action': 1, 'Thriller': 1}],
#  [840, {'Comedy': 1}],
#  [841, {'Horror': 1}],
#  [842, {'Horror': 1}],
#  [843, {'Drama': 1}],
#  [844, {'Drama': 1}],
#  [846, {'Drama': 1}],
#  [847, {'Comedy': 1, 'Drama': 1}],
#  [848, {'Drama': 1}],
#  [849, {'Action': 1, 'Adventure': 1, 'Sci-Fi': 1, 'Thriller': 1}],
#  [850, {'Crime': 1, 'Drama': 1}],
#  [851, {'Drama': 1}],
#  [852, {'Comedy': 1, 'Romance': 1}],
#  [853, {'Drama': 1}],
#  [854, {'Drama': 1}],
#  [858, {'Action': 1, 'Crime': 1, 'Drama': 1}],
#  [859, {'Documentary': 1}],
#  [860, {'Comedy': 1}],
#  [861, {'Action': 1, 'Thriller': 1}],
#  [862, {'Drama': 1}],
#  [863, {'Comedy': 1}],
#  [864, {'Comedy': 1, 'Drama': 1}],
#  [865, {'Drama': 1}],
#  [866, {'Crime': 1, 'Drama': 1, 'Romance': 1, 'Thriller': 1}],
#  [867, {'Comedy': 1, 'Crime': 1}],
#  [868, {'Comedy': 1}],
#  [869, {'Crime': 1}],
#  [870, {'Comedy': 1}],
#  [872, {'Drama': 1}],
#  [874, {'Crime': 1, 'Drama': 1}],
#  [875, {'Drama': 1}],
#  [876, {'Action': 1}],
#  [877, {'Drama': 1}],
#  [878, {'Drama': 1}],
#  [879, {'Horror': 1}],
#  [880, {'Sci-Fi': 1, 'Thriller': 1}],
#  [881, {"Children's": 1, 'Comedy': 1}],
#  [882, {'Drama': 1, 'Thriller': 1}],
#  [884, {'Drama': 1}],
#  [885, {"Children's": 1, 'Drama': 1, 'Fantasy': 1}],
#  [886, {'Action': 1}],
#  [887, {'Drama': 1}],
#  [888, {'Animation': 1, "Children's": 1}],
#  [889, {'Romance': 1}],
#  [891, {'Horror': 1, 'Thriller': 1}],
#  [892, {'Comedy': 1, 'Drama': 1, 'Romance': 1}],
#  [893, {'Drama': 1}],
#  [895, {'Drama': 1}],
#  [896, {'Drama': 1}],
#  [897, {'Adventure': 1, 'War': 1}],
#  [898, {'Comedy': 1, 'Romance': 1}],
#  [899, {'Musical': 1, 'Romance': 1}],
#  [900, {'Musical': 1, 'Romance': 1}],
#  [901, {'Comedy': 1, 'Musical': 1}],
#  [902, {'Drama': 1, 'Romance': 1}],
#  [903, {'Mystery': 1, 'Thriller': 1}],
#  [904, {'Mystery': 1, 'Thriller': 1}],
#  [905, {'Comedy': 1}],
#  [906, {'Mystery': 1, 'Thriller': 1}],
#  [907, {'Comedy': 1, 'Musical': 1, 'Romance': 1}],
#  [908, {'Drama': 1, 'Thriller': 1}],
#  [909, {'Comedy': 1, 'Drama': 1}],
#  [910, {'Comedy': 1, 'Crime': 1}],
#  [911, {'Comedy': 1, 'Mystery': 1, 'Romance': 1, 'Thriller': 1}],
#  [912, {'Drama': 1, 'Romance': 1, 'War': 1}],
#  [913, {'Film-Noir': 1, 'Mystery': 1}],
#  [914, {'Musical': 1, 'Romance': 1}],
#  [915, {'Comedy': 1, 'Romance': 1}],
#  [916, {'Comedy': 1, 'Romance': 1}],
#  [917, {"Children's": 1, 'Drama': 1}],
#  [918, {'Musical': 1}],
#  [919, {'Adventure': 1, "Children's": 1, 'Drama': 1, 'Musical': 1}],
#  [920, {'Drama': 1, 'Romance': 1, 'War': 1}],
#  [921, {'Comedy': 1}],
#  [922, {'Film-Noir': 1}],
#  [923, {'Drama': 1}],
#  [924, {'Drama': 1, 'Mystery': 1, 'Sci-Fi': 1, 'Thriller': 1}],
#  [925, {'Adventure': 1, 'Romance': 1}],
#  [926, {'Drama': 1}],
#  [927, {'Comedy': 1}],
#  [928, {'Romance': 1, 'Thriller': 1}],
#  [929, {'Thriller': 1}],
#  [930, {'Film-Noir': 1, 'Romance': 1, 'Thriller': 1}],
#  [931, {'Mystery': 1, 'Romance': 1, 'Thriller': 1}],
#  [932, {'Romance': 1}],
#  [933, {'Comedy': 1, 'Romance': 1, 'Thriller': 1}],
#  [934, {'Comedy': 1}],
#  [935, {'Comedy': 1, 'Musical': 1}],
#  [936, {'Comedy': 1, 'Romance': 1}],
#  [937, {'Comedy': 1, 'Romance': 1}],
#  [938, {'Musical': 1}],
#  [939, {'Comedy': 1, 'Drama': 1}],
#  [940, {'Action': 1, 'Adventure': 1}],
#  [941, {'Adventure': 1}],
#  [942, {'Crime': 1, 'Film-Noir': 1, 'Mystery': 1}],
#  [943, {'Drama': 1, 'Romance': 1}],
#  [944, {'Drama': 1}],
#  [945, {'Comedy': 1, 'Musical': 1, 'Romance': 1}],
#  [946, {'Comedy': 1, 'Drama': 1, 'War': 1}],
#  [947, {'Comedy': 1}],
#  [948, {'Drama': 1}],
#  [949, {'Drama': 1}],
#  [950, {'Mystery': 1}],
#  [951, {'Comedy': 1}],
#  [952, {'Adventure': 1, 'Comedy': 1}],
#  [953, {'Drama': 1}],
#  [954, {'Drama': 1}],
#  [955, {'Comedy': 1}],
#  [956, {'Drama': 1, 'Romance': 1}],
#  [957, {'Drama': 1}],
#  [958, {'Comedy': 1, 'Mystery': 1}],
#  [959, {'Drama': 1}],
#  [960, {'Crime': 1, 'Drama': 1}],
#  [961, {'Drama': 1}],
#  [962, {'Crime': 1, 'Drama': 1}],
#  [963, {'Musical': 1}],
#  [964, {'Western': 1}],
#  [965, {'Thriller': 1}],
#  [966, {'Drama': 1}],
#  [967, {'Western': 1}],
#  [968, {'Horror': 1, 'Sci-Fi': 1}],
#  [969, {'Action': 1, 'Adventure': 1, 'Romance': 1, 'War': 1}],
#  [970, {'Comedy': 1, 'Drama': 1}],
#  [971, {'Drama': 1}],
#  [972, {'Drama': 1}],
#  [973, {'Drama': 1}],
#  [974, {'Drama': 1, 'Romance': 1}],
#  [975, {'Comedy': 1, 'Musical': 1}],
#  [976, {'Romance': 1, 'War': 1}],
#  [977, {'Mystery': 1}],
#  [978, {'Drama': 1}],
#  [980, {'Action': 1}],
#  [981, {'Drama': 1}],
#  [982, {'Drama': 1}],
#  [984, {'Comedy': 1, 'Drama': 1}],
#  [985, {'Documentary': 1}],
#  [986, {'Adventure': 1, "Children's": 1}],
#  [987, {'Drama': 1, 'Romance': 1}],
#  [988, {'Comedy': 1, 'Drama': 1}],
#  [989, {'Drama': 1}],
#  [990, {'Action': 1, 'Adventure': 1, 'Thriller': 1}],
#  [991, {'Drama': 1, 'War': 1}],
#  [992, {'Thriller': 1}],
#  [993, {'Drama': 1}],
#  [994, {'Drama': 1}],
#  [996, {'Action': 1, 'Drama': 1, 'Western': 1}],
#  [997, {'Drama': 1, 'Thriller': 1}],
#  [998, {'Action': 1, 'Crime': 1}],
#  [999, {'Crime': 1}],
#  [1000, {'Crime': 1}],
#  [1002, {'Comedy': 1}],
#  [1003, {'Drama': 1, 'Thriller': 1}],
#  [1004, {'Action': 1, 'Thriller': 1}],
#  [1005, {"Children's": 1, 'Comedy': 1}],
#  [1006, {'Drama': 1}],
#  [1007, {"Children's": 1, 'Comedy': 1, 'Western': 1}],
#  [1008, {'Western': 1}],
#  [1009, {'Adventure': 1, "Children's": 1, 'Fantasy': 1}],
#  [1010, {"Children's": 1, 'Comedy': 1}],
#  [1011, {'Adventure': 1, "Children's": 1, 'Comedy': 1}],
#  [1012, {"Children's": 1, 'Drama': 1}],
#  [1013, {"Children's": 1, 'Drama': 1}],
#  [1014, {"Children's": 1, 'Comedy': 1, 'Drama': 1}],
#  [1015, {'Adventure': 1, "Children's": 1}],
#  [1016, {"Children's": 1, 'Comedy': 1}],
#  [1017, {'Adventure': 1, "Children's": 1}],
#  [1018, {"Children's": 1, 'Comedy': 1, 'Mystery': 1}],
#  [1019, {'Adventure': 1, "Children's": 1, 'Fantasy': 1, 'Sci-Fi': 1}],
#  [1020, {'Comedy': 1}],
#  [1021, {"Children's": 1, 'Comedy': 1}],
#  [1022, {'Animation': 1, "Children's": 1, 'Musical': 1}],
#  [1023, {'Animation': 1, "Children's": 1}],
#  [1024, {'Animation': 1, "Children's": 1, 'Musical': 1}],
#  [1025, {'Animation': 1, "Children's": 1}],
#  [1026, {"Children's": 1, 'Drama': 1}],
#  [1027, {'Drama': 1}],
#  [1028, {"Children's": 1, 'Comedy': 1, 'Musical': 1}],
#  [1029, {'Animation': 1, "Children's": 1, 'Musical': 1}],
#  [1030, {'Adventure': 1, 'Animation': 1, "Children's": 1, 'Musical': 1}],
#  [1031, {'Adventure': 1, "Children's": 1, 'Musical': 1}],
#  [1032, {'Animation': 1, "Children's": 1, 'Musical': 1}],
#  [1033, {'Animation': 1, "Children's": 1}],
#  [1034, {'Crime': 1}],
#  [1035, {'Musical': 1}],
#  [1036, {'Action': 1, 'Thriller': 1}],
#  [1037, {'Action': 1, 'Sci-Fi': 1, 'Thriller': 1}],
#  [1038, {'Drama': 1}],
#  [1039, {'Documentary': 1}],
#  [1040, {'Drama': 1}],
#  [1041, {'Drama': 1}],
#  [1042, {'Comedy': 1}],
#  [1043, {'Drama': 1, 'Romance': 1}],
#  [1044, {'Drama': 1}],
#  [1046, {'Drama': 1, 'Romance': 1}],
#  [1047, {'Action': 1, 'Thriller': 1}],
#  [1049, {'Action': 1, 'Adventure': 1}],
#  [1050, {'Documentary': 1, 'Drama': 1}],
#  [1051, {'Drama': 1}],
#  [1053, {'Crime': 1, 'Drama': 1}],
#  [1054, {'Drama': 1}],
#  [1055, {'Thriller': 1}],
#  [1056, {'Drama': 1}],
#  [1057, {'Comedy': 1, 'Musical': 1, 'Romance': 1}],
#  [1058, {'Drama': 1}],
#  [1059, {'Drama': 1, 'Romance': 1}],
#  [1060, {'Comedy': 1, 'Drama': 1}],
#  [1061, {'Crime': 1, 'Drama': 1}],
#  [1062, {'Drama': 1}],
#  [1063, {'Drama': 1}],
#  [1064, {'Animation': 1, "Children's": 1, 'Comedy': 1}],
#  [1066, {'Comedy': 1, 'Musical': 1, 'Romance': 1}],
#  [1067, {'Comedy': 1, 'Musical': 1, 'Romance': 1}],
#  [1068, {'Crime': 1, 'Film-Noir': 1}],
#  ...]

# %%
# %%time
# LightFM用のデータセットの宣言
lightfm_dataset = Dataset()
# ユーザー、アイテム、各特徴量へのenocoder生成
lightfm_dataset.fit(
  users=uq_users, 
  items=uq_items, 
  user_features=set_user_features, 
  item_features=set_item_features
)
# ユーザー特徴量データセットのビルド
u_feat = \
  lightfm_dataset.build_user_features(
    uq_user_features
  )
# アイテム特徴量データセットのビルド
i_feat = \
  lightfm_dataset.build_item_features(
    uq_item_features
  )
# マッピング情報の作成
user_id_map, user_feature_map, \
  item_id_map, item_feature_map = \
  lightfm_dataset.mapping()
# インタラクションデータのリスト化
list_dataset = list(
  dataset[
    ['user_id', 'item_id', 'rating']
  ].itertuples(index=False, name=None)
)
# インタラクションデータのビルド
interactions, weights = \
  lightfm_dataset.build_interactions(
    list_dataset
  )
# Out:
# CPU times: user 2.91 s, sys: 101 ms, total: 3.01 s
# Wall time: 3.03 s

# %%
# %%time
# モデルの宣言
model = LightFM(
  no_components=latent, #潜在因子の次元
  loss='bpr',           #損失関数はBPR
  learning_rate=0.01,   #学習率
  user_alpha=0.01,      #user特徴量の正則化
  item_alpha=0.01       #item特徴量の正則化
)
# モデルの学習
model.fit(
  weights,              #explicitデータ
  user_features=u_feat, #user特徴量情報
  item_features=i_feat, #item特徴量情報
  epochs=5,             #エポック数
  num_threads=4         #並列化数を指定
)
# Out:
# CPU times: user 57.7 s, sys: 52.7 ms, total: 57.8 s
# Wall time: 35.2 s

# %%
# %%time
prediction = model.predict(
  user_ids=\
    dataset.user_id.map(user_id_map).values,
  item_ids=\
    dataset.item_id.map(item_id_map).values,
  user_features=u_feat,
  item_features=i_feat, 
  num_threads=4)
# Out:
# CPU times: user 662 ms, sys: 8.97 ms, total: 671 ms
# Wall time: 371 ms

# %%
# %%time
# ユニークなユーザーIDのリストを作成する
uq_users = np.sort(dataset.user_id.unique().tolist())
# ユニークなアイテムIDのリストを作成する
uq_items = np.sort(dataset.item_id.unique().tolist())

# 推薦結果を格納するテーブルを作成する
df_recommend_list = pd.DataFrame(
  columns=['user_id', 'item_id', 'score', 'rank']
)

# 各ユーザーに対して、トップ10アイテムを絞り込む
for user_id in uq_users:

  # すでに接触したアイテムを除外する
  i_list = list(
    set(uq_items) - 
    set(dataset[
      dataset['user_id']==user_id
    ]['item_id'].tolist())
  )

  u_list = [user_id] * len(i_list)
  df_predict = pd.DataFrame()
  df_predict['user_id'] = u_list
  df_predict['item_id'] = i_list
  
  # 対象ユーザーと未接触アイテムでスコア予測を行う
  prediction = model.predict(
    user_ids=\
      df_predict.user_id.map(user_id_map).values,
    item_ids=\
      df_predict.item_id.map(item_id_map).values,
    user_features=u_feat, 
    item_features=i_feat, 
    num_threads=4
  )
  df_predict['score'] = prediction

  #  スコアでの並び替え、トップ10で絞り込み
  df_recommend = df_predict.sort_values(
    'score', ascending=False
  )[:topk]
  df_recommend['rank'] = rank_list

  # 全体テーブルに格納する
  df_recommend_list = \
    df_recommend_list.append(
      df_recommend, 
      ignore_index=True
    )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# CPU times: user 2min 34s, sys: 2.26 s, total: 2min 36s
# Wall time: 2min 29s

# %%
df_recommend_list
# Out:
#       user_id item_id     score rank
# 0           1     480 -1.355063    1
# 1           1    1198 -1.363643    2
# 2           1     589 -1.368019    3
# 3           1    2571 -1.368536    4
# 4           1    2628 -1.371501    5
# ...       ...     ...       ...  ...
# 60395    6040    2916 -3.816613    6
# 60396    6040    1527 -3.816704    7
# 60397    6040    1356 -3.819051    8
# 60398    6040     316 -3.820175    9
# 60399    6040    1676 -3.821200   10
#
# [60400 rows x 4 columns]
